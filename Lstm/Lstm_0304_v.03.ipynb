# %% [markdown]
# <div align='center'><font size="5" color='#353B47'>Predicting Stock Prices</font></div>
# <div align='center'><font size="4" color="#353B47">How to use LSTMs</font></div>
# <br>
# <hr>

# %% [markdown]
# **<font color="blue" size="4">Context</font>**
#
# > This notebook aims at showing a short script on how to predict stock prices using a LSTM model. An introduction has been made about <a href="https://www.kaggle.com/bryanb/introduction-to-time-series-analysis/edit/run/53321733">Time Series Analysis</a>, if you haven't read it yet, do not hesitate to give a look

# %% [markdown]
# **<font color="blue" size="4">Reminder</font>**
#
# > A Time Series is a **time-indexed** series of data. In Finance, a time series tracks the movement of the chosen data points, such as a *security’s price*, over a specified period of time with data points recorded at **regular intervals**.

# %% [markdown]
# <img src="https://miro.medium.com/max/1400/1*NpT5pyemQQsGEHXbfS51Zw.png" width="500">

# %% [markdown]
# **<font color="blue" size="4">Why is it used for ?</font>**
#
# > Time series analysis can be useful to see how a given asset, security, or economic variable changes over time. It can also be used to examine how the changes associated with the chosen data point compare to shifts in other variables over the same time period.
# >
# > For example, suppose you wanted to analyze a time series of daily closing stock prices for a given stock over a period of one year. You would obtain a list of all the closing prices for the stock from each day for the past year and list them in chronological order.

# %% [markdown]
# ## <div id="summary">Summary</div>
#
# **<font size="2"><a href="#chap1">1. Import libraries</a></font>**
# **<br><font size="2"><a href="#chap2">2. Preprocessing</a></font>**
# **<br><font size="2"><a href="#chap3">3. Build LSTM model</a></font>**
# **<br><font size="2"><a href="#chap4">4. Training</a></font>**
# **<br><font size="2"><a href="#chap5">5. Predictions</a></font>**

# %% [markdown]
# # <div id="chap1">1. Import libraries

# %%
import numpy as np
import pandas as pd

import os
import matplotlib.pyplot as plt
# import pandas_datareader as web
import datetime as dt

from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
import yfinance as yf

# %% [markdown]
# **<font size="2"><a href="#summary">Back to summary</a></font>**
#
# ----

# %% [markdown]
# # <div id="chap2">2. Preprocessing

# %%
COMPANY = '^GSPC'

# %%
data = yf.download(COMPANY, start='2018-01-01', end='2020-01-01')
len(data)
# Out:
# [*********************100%***********************]  1 of 1 completed
# 503

# %%
array_data = np.array(data['Close'])
n_data = array_data.size
time_data = np.arange(0, n_data)
Polynomial = np.polyfit(time_data, array_data, 1)
data_notrend = array_data - Polynomial[0] * time_data  # detrended x
data['Close'] = data_notrend

# %%
plt.figure(figsize=(20, 8))
plt.plot(data['Close'], 'black', label=f"Actual {COMPANY} price")
plt.title(f"{COMPANY} share price, data")
plt.xlabel("time")
plt.ylabel(f"{COMPANY} share price")
plt.legend()
plt.show()

# %%
train_data = data[0:200]
valid_data = data[200:400]
test_data = data[400:500]

# %%
plt.figure(figsize=(20, 8))
plt.plot(train_data['Close'], 'black', label=f"Actual {COMPANY} price")
plt.title(f"{COMPANY} share price, train")
plt.xlabel("time")
plt.ylabel(f"{COMPANY} share price")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.plot(valid_data['Close'], 'black', label=f"Actual {COMPANY} price")
plt.title(f"{COMPANY} share price, valid")
plt.xlabel("time")
plt.ylabel(f"{COMPANY} share price")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.plot(test_data['Close'], 'black', label=f"Actual {COMPANY} price")
plt.title(f"{COMPANY} share price, test")
plt.xlabel("time")
plt.ylabel(f"{COMPANY} share price")
plt.legend()
plt.show()

# %%
# Normalize data
scaler = MinMaxScaler(feature_range=(-1,1))
scaled_data = scaler.fit_transform(train_data['Close'].values.reshape(-1,1))

# %%
# how many days do i want to base my predictions on ?
prediction_days = 30

x_train = []
y_train = []

for x in range(prediction_days, len(scaled_data)):
    x_train.append(scaled_data[x - prediction_days:x, 0])
    y_train.append(scaled_data[x, 0])
    
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %% [markdown]
# **<font size="2"><a href="#summary">Back to summary</a></font>**
#
# ----

# %% [markdown]
# # <div id="chap3">3. Build LSTM model

# %% [markdown]
# **<font color="blue" size="4">What is a LSTM ?</font>**
#
# > Long Short Term Memory networks – usually just called “LSTMs” – are a special kind of RNN, capable of learning long-term dependencies. Introduced by Hochreiter & Schmidhuber (1997), and were refined and popularized by many people in following work. They work tremendously well on a large variety of problems, and are now widely used.
# >
# > LSTMs are explicitly designed to avoid the long-term dependency problem. Remembering information for long periods of time is practically their default behavior, not something they struggle to learn!
# >
# > All recurrent neural networks have the form of a chain of repeating modules of neural network.

# %% [markdown]
# You can find more details here: http://colah.github.io/posts/2015-08-Understanding-LSTMs/

# %%
def LSTM_model():
    
    model = Sequential()
    
    model.add(LSTM(units = 50, return_sequences = True, input_shape = (x_train.shape[1],1)))
    model.add(Dropout(0.2))

    model.add(LSTM(units = 50, return_sequences = True))
    model.add(Dropout(0.2))

    model.add(LSTM(units = 50))
    model.add(Dropout(0.2))
    
    model.add(Dense(units=1))
    
    return model

# %% [markdown]
# **<font size="2"><a href="#summary">Back to summary</a></font>**
#
# ----

# %% [markdown]
# # <div id="chap4">4. Training

# %%
# model = LSTM_model()
# model.summary()
# model.compile(optimizer='adam', loss='mean_squared_error')

# # Define callbacks
# # Save weights only for best model
# checkpointer = ModelCheckpoint(filepath = 'weights_best.hdf5', verbose = 2, save_best_only = True)
# earlystopper = EarlyStopping(monitor = 'val_loss', patience = 5, verbose = 2)

# history = model.fit(x_train, y_train, epochs=25, batch_size = 32, callbacks = [checkpointer, earlystopper], validation_split = 0.2)

# # plot loss curves
# plt.plot(history.history['loss'], label='train')
# plt.plot(history.history['val_loss'], label='validation')
# plt.legend()
# plt.show()

# %%
model = LSTM_model()
model.summary()
model.compile(optimizer='adam', 
              loss='mean_squared_error')
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_15 (LSTM)              (None, 30, 50)            10400
#
#  dropout_15 (Dropout)        (None, 30, 50)            0
#
#  lstm_16 (LSTM)              (None, 30, 50)            20200
#
#  dropout_16 (Dropout)        (None, 30, 50)            0
#
#  lstm_17 (LSTM)              (None, 50)                20200
#
#  dropout_17 (Dropout)        (None, 50)                0
#
#  dense_5 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
# # Define callbacks

# # Save weights only for best model
# checkpointer = ModelCheckpoint(filepath = 'weights_best.hdf5', 
#                                verbose = 2, 
#                                save_best_only = True)

# model.fit(x_train, 
#           y_train, 
#           epochs=25, 
#           batch_size = 32,
#           callbacks = [checkpointer])

# %%
# Define callbacks
# Save weights only for best model
checkpointer = ModelCheckpoint(filepath = 'weights_best.hdf5', verbose = 2, save_best_only = True)
earlystopper = EarlyStopping(monitor = 'val_loss', patience = 5, verbose = 2)

history = model.fit(x_train, y_train, epochs=25, batch_size = 32, callbacks = [checkpointer, earlystopper], validation_split = 0.2)
# Out:
# Epoch 1/25
# 4/5 [=======================>......] - ETA: 0s - loss: 0.1268
# Epoch 1: val_loss improved from inf to 0.17756, saving model to weights_best.hdf5
# 5/5 [==============================] - 8s 401ms/step - loss: 0.1234 - val_loss: 0.1776
# Epoch 2/25
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0812
# Epoch 2: val_loss improved from 0.17756 to 0.15059, saving model to weights_best.hdf5
# 5/5 [==============================] - 0s 74ms/step - loss: 0.0855 - val_loss: 0.1506
# Epoch 3/25
# 5/5 [==============================] - ETA: 0s - loss: 0.0785
# Epoch 3: val_loss improved from 0.15059 to 0.14764, saving model to weights_best.hdf5
# 5/5 [==============================] - 0s 70ms/step - loss: 0.0785 - val_loss: 0.1476
# Epoch 4/25
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0745
# Epoch 4: val_loss improved from 0.14764 to 0.13902, saving model to weights_best.hdf5
# 5/5 [==============================] - 0s 70ms/step - loss: 0.0732 - val_loss: 0.1390
# Epoch 5/25
# 5/5 [==============================] - ETA: 0s - loss: 0.0721
# Epoch 5: val_loss improved from 0.13902 to 0.13512, saving model to weights_best.hdf5
# 5/5 [==============================] - 0s 75ms/step - loss: 0.0721 - val_loss: 0.1351
# Epoch 6/25
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0745
# Epoch 6: val_loss improved from 0.13512 to 0.12794, saving model to weights_best.hdf5
# 5/5 [==============================] - 0s 80ms/step - loss: 0.0711 - val_loss: 0.1279
# Epoch 7/25
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0705
# Epoch 7: val_loss improved from 0.12794 to 0.11895, saving model to weights_best.hdf5
# 5/5 [==============================] - 0s 79ms/step - loss: 0.0685 - val_loss: 0.1189
# Epoch 8/25
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0672
# Epoch 8: val_loss improved from 0.11895 to 0.11619, saving model to weights_best.hdf5
# 5/5 [==============================] - 0s 71ms/step - loss: 0.0682 - val_loss: 0.1162
# Epoch 9/25
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0629
# Epoch 9: val_loss improved from 0.11619 to 0.11584, saving model to weights_best.hdf5
# 5/5 [==============================] - 0s 70ms/step - loss: 0.0651 - val_loss: 0.1158
# Epoch 10/25
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0668
# Epoch 10: val_loss did not improve from 0.11584
# 5/5 [==============================] - 0s 77ms/step - loss: 0.0641 - val_loss: 0.1204
# Epoch 11/25
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0626
# Epoch 11: val_loss did not improve from 0.11584
# 5/5 [==============================] - 0s 62ms/step - loss: 0.0660 - val_loss: 0.1162
# Epoch 12/25
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0621
# Epoch 12: val_loss improved from 0.11584 to 0.11282, saving model to weights_best.hdf5
# 5/5 [==============================] - 0s 73ms/step - loss: 0.0611 - val_loss: 0.1128
# Epoch 13/25
# 5/5 [==============================] - ETA: 0s - loss: 0.0605
# Epoch 13: val_loss improved from 0.11282 to 0.11055, saving model to weights_best.hdf5
# 5/5 [==============================] - 0s 76ms/step - loss: 0.0605 - val_loss: 0.1105
# Epoch 14/25
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0598
# Epoch 14: val_loss improved from 0.11055 to 0.10869, saving model to weights_best.hdf5
# 5/5 [==============================] - 0s 69ms/step - loss: 0.0593 - val_loss: 0.1087
# Epoch 15/25
# 5/5 [==============================] - ETA: 0s - loss: 0.0569
# Epoch 15: val_loss improved from 0.10869 to 0.10663, saving model to weights_best.hdf5
# 5/5 [==============================] - 0s 71ms/step - loss: 0.0569 - val_loss: 0.1066
# Epoch 16/25
# 5/5 [==============================] - ETA: 0s - loss: 0.0565
# Epoch 16: val_loss improved from 0.10663 to 0.10163, saving model to weights_best.hdf5
# 5/5 [==============================] - 0s 68ms/step - loss: 0.0565 - val_loss: 0.1016
# Epoch 17/25
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0520
# Epoch 17: val_loss did not improve from 0.10163
# 5/5 [==============================] - 0s 64ms/step - loss: 0.0519 - val_loss: 0.1027
# Epoch 18/25
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0530
# Epoch 18: val_loss did not improve from 0.10163
# 5/5 [==============================] - 0s 63ms/step - loss: 0.0515 - val_loss: 0.1054
# Epoch 19/25
# 5/5 [==============================] - ETA: 0s - loss: 0.0516
# Epoch 19: val_loss improved from 0.10163 to 0.09943, saving model to weights_best.hdf5
# 5/5 [==============================] - 0s 72ms/step - loss: 0.0516 - val_loss: 0.0994
# Epoch 20/25
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0480
# Epoch 20: val_loss improved from 0.09943 to 0.09621, saving model to weights_best.hdf5
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0492 - val_loss: 0.0962
# Epoch 21/25
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0475
# Epoch 21: val_loss improved from 0.09621 to 0.09485, saving model to weights_best.hdf5
# 5/5 [==============================] - 0s 70ms/step - loss: 0.0472 - val_loss: 0.0949
# Epoch 22/25
# 5/5 [==============================] - ETA: 0s - loss: 0.0450
# Epoch 22: val_loss improved from 0.09485 to 0.09475, saving model to weights_best.hdf5
# 5/5 [==============================] - 0s 80ms/step - loss: 0.0450 - val_loss: 0.0947
# Epoch 23/25
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0445
# Epoch 23: val_loss did not improve from 0.09475
# 5/5 [==============================] - 0s 68ms/step - loss: 0.0443 - val_loss: 0.0955
# Epoch 24/25
# 5/5 [==============================] - ETA: 0s - loss: 0.0423
# Epoch 24: val_loss improved from 0.09475 to 0.09291, saving model to weights_best.hdf5
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0423 - val_loss: 0.0929
# Epoch 25/25
# 5/5 [==============================] - ETA: 0s - loss: 0.0418
# Epoch 25: val_loss did not improve from 0.09291
# 5/5 [==============================] - 0s 64ms/step - loss: 0.0418 - val_loss: 0.0936

# %%
# Loss
fig, ax = plt.subplots(figsize=(8,4))
plt.title('loss')
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss', linestyle='--')
plt.legend()
plt.show()

# %% [markdown]
# **<font size="2"><a href="#summary">Back to summary</a></font>**
#
# ----

# %% [markdown]
# # <div id="chap5">5. Predictions

# %%
# test model accuracy on existing data

actual_prices = valid_data['Close'].values
total_dataset = pd.concat((train_data['Close'], valid_data['Close']), axis=0)
model_inputs = total_dataset[len(total_dataset) - len(valid_data) - prediction_days:].values
model_inputs = model_inputs.reshape(-1,1)
model_inputs = scaler.transform(model_inputs)

# %%
x_test = []
for x in range(prediction_days, len(model_inputs)):
    x_test.append(model_inputs[x-prediction_days:x, 0])

x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1] ,1))

predicted_prices = model.predict(x_test)
predicted_prices = scaler.inverse_transform(predicted_prices)
# Out:
# 7/7 [==============================] - 0s 20ms/step

# %%
plt.figure(figsize=(20, 8))
plt.plot(actual_prices, color='black', label=f"Actual {COMPANY} price")
plt.plot(predicted_prices, color= 'green', label=f"predicted {COMPANY} price")
plt.title(f"{COMPANY} share price")
plt.xlabel("time")
plt.ylabel(f"{COMPANY} share price")
plt.legend()
plt.show()

# %%
# # predicting next day
# real_data = [model_inputs[len(model_inputs)+1 - prediction_days:len(model_inputs+1),0]]
# real_data = np.array(real_data)
# real_data = np.reshape(real_data, (real_data.shape[0], real_data.shape[1], 1))

# %%
# prediction = model.predict(real_data)
# prediction = scaler.inverse_transform(prediction)
# print(f"prediction: {prediction}")

# %%
# predicting next 10 days
real_data = [model_inputs[len(model_inputs) - prediction_days:len(model_inputs), 0]]
real_data = np.array(real_data)
real_data = np.reshape(real_data, (real_data.shape[0], real_data.shape[1], 1))

# %%
predictions = []
for i in range(100):
    prediction = model.predict(real_data)
    prediction = scaler.inverse_transform(prediction)
    predictions.append(prediction)
    real_data = np.append(real_data[:, 1:, :], np.expand_dims(prediction, axis=1), axis=1)


print(f"predictions: {predictions}")
# Out:
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# predictions: [array([[2685.001]], dtype=float32), array([[2721.0115]], dtype=float32), array([[2766.9106]], dtype=float32), array([[2805.937]], dtype=float32), array([[2835.7825]], dtype=float32), array([[2857.8765]], dtype=float32), array([[2874.0686]], dtype=float32), array([[2885.9182]], dtype=float32), array([[2894.607]], dtype=float32), array([[2901.0237]], dtype=float32), array([[2905.812]], dtype=float32), array([[2909.423]], dtype=float32), array([[2912.1804]], dtype=float32), array([[2914.3235]], dtype=float32), array([[2916.0146]], dtype=float32), array([[2917.3833]], dtype=float32), array([[2918.5168]], dtype=float32), array([[2919.472]], dtype=float32), array([[2920.2769]], dtype=float32), array([[2920.9624]], dtype=float32), array([[2921.5496]], dtype=float32), array([[2922.064]], dtype=float32), array([[2922.5164]], dtype=float32), array([[2922.8972]], dtype=float32), array([[2923.2073]], dtype=float32), array([[2923.4387]], dtype=float32), array([[2923.5974]], dtype=float32), array([[2923.806]], dtype=float32), array([[2924.1523]], dtype=float32), array([[2924.6926]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32), array([[2926.0393]], dtype=float32)]

# %%
import matplotlib.pyplot as plt

# 將預測結果轉換成numpy array並展平
predictions = np.array(predictions).flatten()

# 畫出實際價格和預測價格的曲線
plt.figure(figsize=(20, 8))
plt.plot(range(len(actual_prices), len(actual_prices)+len(predictions)), test_data['Close'])
plt.plot(range(0, len(actual_prices)), actual_prices)
plt.plot(range(len(actual_prices), len(actual_prices)+len(predictions)), predictions)
plt.xlabel("Day")
plt.ylabel("Price")
plt.legend(["true_data", "Actual Price", "Predicted Price"])
plt.show()

# %%
import matplotlib.pyplot as plt

# 將預測結果轉換成numpy array並展平
predictions = np.array(predictions).flatten()

# 畫出實際價格和預測價格的曲線
plt.plot(range(len(actual_prices), len(actual_prices)+len(predictions)), true_data['Close'])

# plt.plot(range(0, len(actual_prices)), actual_prices)
plt.plot(range(len(actual_prices), len(actual_prices)+len(predictions)), predictions)
plt.xlabel("Day")
plt.ylabel("Price")
plt.legend(["true_data", "Predicted Price"])
plt.show()

# %% [markdown]
# **<font size="2"><a href="#summary">Back to summary</a></font>**
#
# ----

# %% [markdown]
# # References
#
# * <a href = 'https://www.kaggle.com/bryanb/introduction-to-time-series-analysis/edit/run/53321733'>My notebook on Time series analysis</a>
# * <a href = 'http://colah.github.io/posts/2015-08-Understanding-LSTMs/'>LSTM Explanations</a>
# * <a href = 'https://www.kaggle.com/datasets/bryanb/cac40-stocks-dataset'>CAC 40 dataset</a>

# %% [markdown]
# <hr>
# <br>
# <div align='justify'><font color="#353B47" size="4">Thank you for taking the time to read this notebook. I hope that I was able to answer your questions or your curiosity and that it was quite understandable. <u>any constructive comments are welcome</u>. They help me progress and motivate me to share better quality content. I am above all a passionate person who tries to advance my knowledge but also that of others. If you liked it, feel free to <u>upvote and share my work.</u> </font></div>
# <br>
# <div align='center'><font color="#353B47" size="3">Thank you and may passion guide you.</font></div>
