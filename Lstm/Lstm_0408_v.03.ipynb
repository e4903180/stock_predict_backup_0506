# %% [markdown]
# # <div id="chap1">1. Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt

# 設定波形參數
amplitude = 1  # 振幅
frequency = 0.05  # 頻率
phase = 0      # 相位
duration = 6000   # 時間長度，單位為秒
sampling_rate = 1  # 取樣率，單位為 Hz

# 計算波形數據
time = np.linspace(0, duration, int(sampling_rate * duration), endpoint=False)
waveform = amplitude * np.sin(2 * np.pi * frequency * time + phase)

# 繪製波形圖
plt.figure(figsize=(20, 8))
plt.plot(waveform)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.xlim(0,100)
plt.show()

# %%
len(waveform)
# Out:
# 6000

# %%
import numpy as np
import pandas as pd

import os
import matplotlib.pyplot as plt
# import pandas_datareader as web
import datetime as dt

from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.random import shuffle

# %%
import yfinance as yf

# %% [markdown]
# # <div id="chap2">2. Preprocessing

# %%
stock_name = "^GSPC"
date_predict_start = '2019-01-01'
data_range = 250
slide_range = 10
n_slide = 10
pv_range = 2
# n_harm_lower_limit = 1
# n_harm_upper_limit = 50
# fit_method = 'rmse'
# pv_method = 'CL'

# %%
COMPANY = '^GSPC'

# %%
data = yf.download(COMPANY, start='1999-01-01', end='2019-06-30')
len(data)
# Out:
# [*********************100%***********************]  1 of 1 completed
# 5155

# %%
data['Close'] = waveform[:len(data)]

# %%
array_data = np.array(data['Close'])
n_data = array_data.size
time_data = np.arange(0, n_data)
Polynomial = np.polyfit(time_data, array_data, 1)
data_notrend = array_data - Polynomial[0] * time_data  # detrended x
data['Close'] = data_notrend

# %%
train_data = data.loc[data.index < date_predict_start]
print(len(train_data))
test_data = data.loc[data.index > date_predict_start]
print(len(test_data))
# Out:
# 5031
# 124

# %%
plt.figure(figsize=(20, 8))
plt.plot(data['Close'], 'black', label=f"Actual {COMPANY} price")
plt.title(f"{COMPANY} share price, data")
plt.xlabel("time")
plt.ylabel(f"{COMPANY} share price")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.plot(train_data['Close'], 'black', label=f"Actual {COMPANY} price")
plt.title(f"{COMPANY} share price, train")
plt.xlabel("time")
plt.ylabel(f"{COMPANY} share price")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.plot(test_data['Close'], 'black', label=f"Actual {COMPANY} price")
plt.title(f"{COMPANY} share price, test")
plt.xlabel("time")
plt.ylabel(f"{COMPANY} share price")
plt.legend()
plt.show()

# %%
# Normalize data
scaler = MinMaxScaler(feature_range=(-1,1))
scaled_data = scaler.fit_transform(train_data['Close'].values.reshape(-1,1))

# %%
plt.plot(scaled_data)

# %%
# how many days do i want to base my predictions on ?
base_day = 250
prediction_day = 30
x_train = []
y_train = []
slide = 10
# 從base_day開始，往前提取base_day天的數據，作為輸入變量x_train，並將當前價格作為輸出變量y_train
for x in range(base_day+prediction_day, len(scaled_data), slide):
    x_train.append(scaled_data[x-base_day-prediction_day:x-prediction_day, 0])
    y_train.append(scaled_data[x-prediction_day:x, 0])
    
x_train, y_train = np.array(x_train), np.array(y_train)

# # 將x_train數組的形狀轉換為（樣本數，天數，特徵數）的形式，這裡的特徵數為1
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = np.reshape(y_train, (y_train.shape[0], y_train.shape[1], 1))

# %%
x_train.shape
# Out:
# (476, 250, 1)

# %%
y_train.shape
# Out:
# (476, 30, 1)

# %% [markdown]
# # <div id="chap3">3. Build LSTM model

# %%
def LSTM_model(prediction_day):
    
    model = Sequential()
    
    model.add(LSTM(units = 256, return_sequences = True, input_shape = (x_train.shape[1],1)))
    model.add(Dropout(0.4))

    model.add(LSTM(units = 128, return_sequences = True))
    model.add(Dropout(0.4))

    model.add(LSTM(units = 64))
    model.add(Dropout(0.4))
    
    model.add(Dense(units=prediction_day))
    
    return model

# %% [markdown]
# # <div id="chap4">4. Training

# %%
# model = LSTM_model()
# model.summary()
# model.compile(optimizer='adam', loss='mean_squared_error')

# # Define callbacks
# # Save weights only for best model
# checkpointer = ModelCheckpoint(filepath = 'weights_best.hdf5', verbose = 2, save_best_only = True)
# earlystopper = EarlyStopping(monitor = 'val_loss', patience = 5, verbose = 2)

# history = model.fit(x_train, y_train, epochs=25, batch_size = 32, callbacks = [checkpointer, earlystopper], validation_split = 0.2)

# # plot loss curves
# plt.plot(history.history['loss'], label='train')
# plt.plot(history.history['val_loss'], label='validation')
# plt.legend()
# plt.show()

# %%
model = LSTM_model(prediction_day)
model.summary()
model.compile(optimizer='adam', 
              loss='mean_squared_error')
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 250, 256)          264192
#
#  dropout (Dropout)           (None, 250, 256)          0
#
#  lstm_1 (LSTM)               (None, 250, 128)          197120
#
#  dropout_1 (Dropout)         (None, 250, 128)          0
#
#  lstm_2 (LSTM)               (None, 64)                49408
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 30)                1950
#
# =================================================================
# Total params: 512,670
# Trainable params: 512,670
# Non-trainable params: 0
# _________________________________________________________________

# %%
# # Define callbacks

# # Save weights only for best model
# checkpointer = ModelCheckpoint(filepath = 'weights_best.hdf5', 
#                                verbose = 2, 
#                                save_best_only = True)

# model.fit(x_train, 
#           y_train, 
#           epochs=25, 
#           batch_size = 32,
#           callbacks = [checkpointer])

# %%
# Define callbacks
# Save weights only for best model
checkpointer = ModelCheckpoint(filepath = 'weights_best.hdf5', verbose = 2, save_best_only = True)
earlystopper = EarlyStopping(monitor = 'val_loss', patience = 10, verbose = 2)
history = model.fit(x_train, y_train, epochs=25, batch_size=32, callbacks = [checkpointer, earlystopper], validation_split = 0.2, shuffle=True)
# Out:
# Epoch 1/25
# 12/12 [==============================] - ETA: 0s - loss: 0.3452
# Epoch 1: val_loss improved from inf to 0.12607, saving model to weights_best.hdf5
# 12/12 [==============================] - 28s 2s/step - loss: 0.3452 - val_loss: 0.1261
# Epoch 2/25
# 12/12 [==============================] - ETA: 0s - loss: 0.1343
# Epoch 2: val_loss improved from 0.12607 to 0.02468, saving model to weights_best.hdf5
# 12/12 [==============================] - 20s 2s/step - loss: 0.1343 - val_loss: 0.0247
# Epoch 3/25
# 12/12 [==============================] - ETA: 0s - loss: 0.0801
# Epoch 3: val_loss improved from 0.02468 to 0.00944, saving model to weights_best.hdf5
# 12/12 [==============================] - 24s 2s/step - loss: 0.0801 - val_loss: 0.0094
# Epoch 4/25
# 12/12 [==============================] - ETA: 0s - loss: 0.0617
# Epoch 4: val_loss improved from 0.00944 to 0.00391, saving model to weights_best.hdf5
# 12/12 [==============================] - 25s 2s/step - loss: 0.0617 - val_loss: 0.0039
# Epoch 5/25
# 12/12 [==============================] - ETA: 0s - loss: 0.0508
# Epoch 5: val_loss improved from 0.00391 to 0.00205, saving model to weights_best.hdf5
# 12/12 [==============================] - 22s 2s/step - loss: 0.0508 - val_loss: 0.0020
# Epoch 6/25
# 12/12 [==============================] - ETA: 0s - loss: 0.0439
# Epoch 6: val_loss improved from 0.00205 to 0.00154, saving model to weights_best.hdf5
# 12/12 [==============================] - 22s 2s/step - loss: 0.0439 - val_loss: 0.0015
# Epoch 7/25
# 12/12 [==============================] - ETA: 0s - loss: 0.0400
# Epoch 7: val_loss did not improve from 0.00154
# 12/12 [==============================] - 24s 2s/step - loss: 0.0400 - val_loss: 0.0028
# Epoch 8/25
# 12/12 [==============================] - ETA: 0s - loss: 0.0356
# Epoch 8: val_loss did not improve from 0.00154
# 12/12 [==============================] - 25s 2s/step - loss: 0.0356 - val_loss: 0.0032
# Epoch 9/25
# 12/12 [==============================] - ETA: 0s - loss: 0.0325
# Epoch 9: val_loss did not improve from 0.00154
# 12/12 [==============================] - 24s 2s/step - loss: 0.0325 - val_loss: 0.0042
# Epoch 10/25
# 12/12 [==============================] - ETA: 0s - loss: 0.0317
# Epoch 10: val_loss improved from 0.00154 to 0.00079, saving model to weights_best.hdf5
# 12/12 [==============================] - 26s 2s/step - loss: 0.0317 - val_loss: 7.9225e-04
# Epoch 11/25
# 12/12 [==============================] - ETA: 0s - loss: 0.0284
# Epoch 11: val_loss improved from 0.00079 to 0.00056, saving model to weights_best.hdf5
# 12/12 [==============================] - 26s 2s/step - loss: 0.0284 - val_loss: 5.5766e-04
# Epoch 12/25
# 12/12 [==============================] - ETA: 0s - loss: 0.0271
# Epoch 12: val_loss did not improve from 0.00056
# 12/12 [==============================] - 27s 2s/step - loss: 0.0271 - val_loss: 0.0011
# Epoch 13/25
# 12/12 [==============================] - ETA: 0s - loss: 0.0259
# Epoch 13: val_loss improved from 0.00056 to 0.00053, saving model to weights_best.hdf5
# 12/12 [==============================] - 25s 2s/step - loss: 0.0259 - val_loss: 5.2974e-04
# Epoch 14/25
# 12/12 [==============================] - ETA: 0s - loss: 0.0248
# Epoch 14: val_loss did not improve from 0.00053
# 12/12 [==============================] - 28s 2s/step - loss: 0.0248 - val_loss: 0.0013
# Epoch 15/25
# 12/12 [==============================] - ETA: 0s - loss: 0.0230
# Epoch 15: val_loss did not improve from 0.00053
# 12/12 [==============================] - 28s 2s/step - loss: 0.0230 - val_loss: 6.0406e-04
# Epoch 16/25
# 12/12 [==============================] - ETA: 0s - loss: 0.0225
# Epoch 16: val_loss did not improve from 0.00053
# 12/12 [==============================] - 28s 2s/step - loss: 0.0225 - val_loss: 0.0052
# Epoch 17/25
# 12/12 [==============================] - ETA: 0s - loss: 0.0225
# Epoch 17: val_loss improved from 0.00053 to 0.00041, saving model to weights_best.hdf5
# 12/12 [==============================] - 27s 2s/step - loss: 0.0225 - val_loss: 4.0968e-04
# Epoch 18/25
# 12/12 [==============================] - ETA: 0s - loss: 0.0216
# Epoch 18: val_loss did not improve from 0.00041
# 12/12 [==============================] - 27s 2s/step - loss: 0.0216 - val_loss: 8.8048e-04
# Epoch 19/25
# 12/12 [==============================] - ETA: 0s - loss: 0.0207
# Epoch 19: val_loss did not improve from 0.00041
# 12/12 [==============================] - 27s 2s/step - loss: 0.0207 - val_loss: 0.0026
# Epoch 20/25
# 12/12 [==============================] - ETA: 0s - loss: 0.0208
# Epoch 20: val_loss did not improve from 0.00041
# 12/12 [==============================] - 27s 2s/step - loss: 0.0208 - val_loss: 8.1291e-04
# Epoch 21/25
# 12/12 [==============================] - ETA: 0s - loss: 0.0185
# Epoch 21: val_loss did not improve from 0.00041
# 12/12 [==============================] - 28s 2s/step - loss: 0.0185 - val_loss: 0.0025
# Epoch 22/25
# 12/12 [==============================] - ETA: 0s - loss: 0.0185
# Epoch 22: val_loss did not improve from 0.00041
# 12/12 [==============================] - 28s 2s/step - loss: 0.0185 - val_loss: 0.0019
# Epoch 23/25
# 12/12 [==============================] - ETA: 0s - loss: 0.0185
# Epoch 23: val_loss did not improve from 0.00041
# 12/12 [==============================] - 28s 2s/step - loss: 0.0185 - val_loss: 4.5779e-04
# Epoch 24/25
# 12/12 [==============================] - ETA: 0s - loss: 0.0178
# Epoch 24: val_loss did not improve from 0.00041
# 12/12 [==============================] - 27s 2s/step - loss: 0.0178 - val_loss: 5.3805e-04
# Epoch 25/25
# 12/12 [==============================] - ETA: 0s - loss: 0.0159
# Epoch 25: val_loss did not improve from 0.00041
# 12/12 [==============================] - 28s 2s/step - loss: 0.0159 - val_loss: 0.0042

# %%
# Loss
fig, ax = plt.subplots(figsize=(8,4))
plt.title('loss')
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss', linestyle='--')
plt.legend()
plt.show()

# %% [markdown]
# # <div id="chap5">5. Predictions

# %%
# test model accuracy on existing data

actual_prices = test_data['Close'].values
total_dataset = pd.concat((train_data['Close'], test_data['Close']), axis=0)
model_inputs = total_dataset[len(total_dataset)-len(test_data)-base_day:].values
model_inputs = model_inputs.reshape(-1,1)
model_inputs = scaler.fit_transform(model_inputs)

# %%
plt.plot(model_inputs)

# %%
x_test = []
y_test = []
for x in range(base_day+prediction_day, len(model_inputs), slide):
    x_test.append(model_inputs[x-base_day-prediction_day:x-prediction_day, 0])
    y_test.append(model_inputs[x-prediction_day:x, 0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1] ,1))

predicted_prices = model.predict(x_test)
# predicted_prices = scaler.inverse_transform(predicted_prices)
print(f"predicted_prices: {predicted_prices}")
# Out:
# 1/1 [==============================] - 2s 2s/step
# predicted_prices: [[ 0.01646652 -0.2831413  -0.4542132  -0.64234364 -0.82730603 -0.8540823
#   -0.86812156 -0.72919345 -0.50806755 -0.26281223 -0.02641454  0.27348754
#    0.517942    0.68469125  0.8287498   0.87890714  0.85372967  0.680174
#    0.5050723   0.26462892 -0.01445183 -0.29234618 -0.50950515 -0.7586593
#   -0.8482643  -0.8603637  -0.80562276 -0.7040855  -0.5117319  -0.3089453 ]
#  [-0.00758666  0.2857836   0.46176267  0.6343639   0.8310033   0.8655604
#    0.870664    0.7327021   0.5004428   0.26967117  0.01846066 -0.2746271
#   -0.52934676 -0.68275464 -0.8200006  -0.87374264 -0.8623969  -0.6853604
#   -0.49364978 -0.24996161  0.01646997  0.28391027  0.5100272   0.75395364
#    0.8577439   0.8641683   0.81238914  0.7133151   0.53594315  0.30432895]
#  [ 0.01646747 -0.2831409  -0.4542101  -0.64233726 -0.82730275 -0.8540804
#   -0.8681217  -0.7291928  -0.50806445 -0.26281226 -0.02641556  0.2734873
#    0.5179416   0.68468815  0.82874906  0.878905    0.85372853  0.6801727
#    0.5050702   0.26462856 -0.01445333 -0.2923466  -0.5095041  -0.75865996
#   -0.84826374 -0.8603611  -0.8056193  -0.7040843  -0.51173097 -0.30894703]
#  [-0.00758622  0.28578365  0.46176493  0.6343692   0.83100605  0.86556304
#    0.8706641   0.732702    0.5004455   0.26967087  0.01846031 -0.27462727
#   -0.5293467  -0.6827572  -0.820001   -0.873744   -0.8623975  -0.6853615
#   -0.4936511  -0.24996156  0.01646852  0.2839098   0.5100283   0.75395256
#    0.85774356  0.86417043  0.8123918   0.71331626  0.535944    0.30432785]
#  [ 0.0164684  -0.2831405  -0.4542071  -0.642331   -0.8272997  -0.85407835
#   -0.8681217  -0.72919214 -0.50806135 -0.2628123  -0.02641653  0.27348706
#    0.51794136  0.6846848   0.8287478   0.8789029   0.85372746  0.68017143
#    0.50506806  0.2646281  -0.01445479 -0.29234698 -0.5095028  -0.7586608
#   -0.8482633  -0.86035854 -0.80561566 -0.70408285 -0.5117301  -0.3089488 ]
#  [-0.00758577  0.28578386  0.46176726  0.6343748   0.83100855  0.8655651
#    0.87066394  0.732702    0.5004481   0.26967072  0.01845993 -0.27462754
#   -0.5293467  -0.6827595  -0.8200013  -0.87374556 -0.8623981  -0.6853627
#   -0.49365234 -0.24996158  0.01646705  0.28390935  0.5100293   0.75395143
#    0.8577436   0.86417276  0.8123946   0.7133173   0.5359445   0.30432656]
#  [ 0.01646936 -0.28314018 -0.45420402 -0.64232486 -0.82729644 -0.8540764
#   -0.8681219  -0.7291918  -0.50805825 -0.26281214 -0.02641755  0.27348688
#    0.517941    0.68468165  0.82874715  0.8789009   0.8537264   0.68017
#    0.505066    0.26462767 -0.0144563  -0.2923475  -0.5095018  -0.75866157
#   -0.8482629  -0.86035615 -0.8056122  -0.7040814  -0.5117291  -0.3089505 ]
#  [-0.00758535  0.28578395  0.46176943  0.63438034  0.83101135  0.8655675
#    0.870664    0.7327019   0.50045085  0.26967052  0.0184596  -0.27462775
#   -0.5293467  -0.68276215 -0.8200018  -0.87374675 -0.8623987  -0.6853639
#   -0.49365374 -0.24996153  0.01646566  0.2839089   0.51003045  0.75395054
#    0.85774344  0.86417496  0.81239724  0.71331835  0.53594524  0.3043253 ]
#  [ 0.0164703  -0.28313982 -0.45420086 -0.6423184  -0.82729346 -0.8540741
#   -0.86812186 -0.72919136 -0.5080552  -0.26281214 -0.02641857  0.2734867
#    0.51794094  0.68467826  0.8287462   0.8788987   0.85372525  0.6801687
#    0.5050639   0.26462725 -0.01445778 -0.2923479  -0.50950074 -0.7586625
#   -0.8482624  -0.8603537  -0.8056089  -0.70408016 -0.5117283  -0.30895224]
#  [-0.00758492  0.28578413  0.4617717   0.6343858   0.83101386  0.86556965
#    0.87066394  0.73270166  0.5004536   0.26967028  0.01845922 -0.274628
#   -0.52934676 -0.68276465 -0.8200022  -0.87374806 -0.8623992  -0.685365
#   -0.49365497 -0.24996153  0.01646419  0.2839084   0.5100316   0.7539493
#    0.857743    0.86417717  0.8124002   0.7133194   0.5359459   0.30432406]]

# %%
type(predicted_prices)
# Out:
# numpy.ndarray

# %%
plt.figure(figsize=(20, 8))
plt.plot(actual_prices, color='black', label=f"Actual {COMPANY} price")
plt.plot(predicted_prices, color='green', label=f"predicted {COMPANY} price")
plt.title(f"{COMPANY} share price")
plt.xlabel("time")
plt.ylabel(f"{COMPANY} share price")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.plot(actual_prices, color='black', label=f"Actual {COMPANY} price")
plt.plot(predicted_prices[0], color= 'green', label=f"predicted {COMPANY} price")
plt.title(f"{COMPANY} share price")
plt.xlabel("time")
plt.ylabel(f"{COMPANY} share price")
plt.xlim(0, 20)
plt.ylim(400, 510)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 8))
for i in range(0, 10):
    plt.plot(predicted_prices[i], label=f"predicted {i}")
plt.title(f"{COMPANY} share price")
plt.xlabel("time")
plt.ylabel(f"{COMPANY} share price")
# plt.xlim(0, 9)
# plt.ylim(400, 510)
plt.legend()
plt.show()

# %%
for num in range(0, 10, 1):
    plt.figure(figsize=(20, 8))
    for i in range(num, num+1):
        start = i
        singal = x_test[start]
        plt.plot(range(start,len(singal)+start), singal, label=f"x_test{i}")
    for i in range(num, num+1):
        start = i
        singal = y_test[start]
        plt.plot(range(start+len(x_test[start]),len(singal)+len(x_test[start])+start), singal, label=f"y_test{i}")
    for i in range(num, num+1):
        start = i
        singal = predicted_prices[start]
        plt.plot(range(start+len(x_test[start]),len(singal)+len(x_test[start])+start), singal, label=f"y_predict{i}")
    plt.xlabel("time")
    plt.title(f"data{i}", fontsize=40)
    plt.legend()
    plt.show()

# %%
def find_data_pv_CL_function(data, pv_range):
    pd.options.mode.chained_assignment = None
    price = data['Close']
    data['peaks'] = pd.Series(dtype='float64')
    data['valleys'] = pd.Series(dtype='float64')
    data['pv'] = pd.Series(dtype='str')
    for idx in range(0, len(price)):
        if idx < pv_range and idx>0:
            if price[idx] == price.iloc[0:pv_range*2+1].max():
                data['peaks'].iloc[idx] = price[idx]
                data['pv'].iloc[idx] = 'peak'
            if price[idx] == price.iloc[0:pv_range*2+1].min():
                data['valleys'].iloc[idx] = price[idx]
                data['pv'].iloc[idx] = 'valley'
        if price[idx] == price.iloc[idx-pv_range:idx+pv_range].max():
            data['peaks'].iloc[idx] = price[idx]
            data['pv'].iloc[idx] = 'peak'
        if price[idx] == price.iloc[idx-pv_range:idx+pv_range].min():
            data['valleys'].iloc[idx] = price[idx]
            data['pv'].iloc[idx] = 'valley'

# %%
predicted_prices.shape[1]
# Out:
# 30

# %%
def find_signal_pv_function(signal_souce, pv_range, test_data, slide):
    pd.options.mode.chained_assignment = None
    signal = {}
    for i in range(0, predicted_prices.shape[0]):
        data = pd.Series(signal_souce[i])
        signal[i] = pd.DataFrame()
        signal[i]['Close'] = data
        signal[i].index = test_data.index[range(i*slide, i*slide+predicted_prices.shape[1])]
        signal[i]['peaks'] = pd.Series(dtype='float64')
        signal[i]['valleys'] = pd.Series(dtype='float64')
        signal[i]['pv'] = pd.Series(dtype='str')
        for idx in range(0, len(data)):
            if idx < pv_range and  idx > 0:
                if data[idx] == data.iloc[0:pv_range*2+1].max():
                    signal[i]['peaks'].iloc[idx] = data[idx]
                    signal[i]['pv'].iloc[idx] = 'peak'
                if data[idx] == data.iloc[0:pv_range*2+1].min():
                    signal[i]['valleys'].iloc[idx] = data[idx]
                    signal[i]['pv'].iloc[idx] = 'valley'
            if data[idx] == data.iloc[idx-pv_range:idx+pv_range].max():
                signal[i]['peaks'].iloc[idx] = data[idx]
                signal[i]['pv'].iloc[idx] = 'peak'
            if data[idx] == data.iloc[idx-pv_range:idx+pv_range].min():
                signal[i]['valleys'].iloc[idx] = data[idx]
                signal[i]['pv'].iloc[idx] = 'valley'
    return signal

# %%
pv_range = 2
test_data['Close'] = actual_prices
find_data_pv_CL_function(test_data, pv_range)
processed_signal = find_signal_pv_function(predicted_prices, pv_range, test_data, slide)

# %%
processed_signal
# Out:
# {0:                Close     peaks   valleys      pv
#  Date
#  2019-01-02  0.016467       NaN       NaN     NaN
#  2019-01-03 -0.283141       NaN       NaN     NaN
#  2019-01-04 -0.454213       NaN       NaN     NaN
#  2019-01-07 -0.642344       NaN       NaN     NaN
#  2019-01-08 -0.827306       NaN       NaN     NaN
#  2019-01-09 -0.854082       NaN       NaN     NaN
#  2019-01-10 -0.868122       NaN -0.868122  valley
#  2019-01-11 -0.729193       NaN       NaN     NaN
#  2019-01-14 -0.508068       NaN       NaN     NaN
#  2019-01-15 -0.262812       NaN       NaN     NaN
#  2019-01-16 -0.026415       NaN       NaN     NaN
#  2019-01-17  0.273488       NaN       NaN     NaN
#  2019-01-18  0.517942       NaN       NaN     NaN
#  2019-01-22  0.684691       NaN       NaN     NaN
#  2019-01-23  0.828750       NaN       NaN     NaN
#  2019-01-24  0.878907  0.878907       NaN    peak
#  2019-01-25  0.853730       NaN       NaN     NaN
#  2019-01-28  0.680174       NaN       NaN     NaN
#  2019-01-29  0.505072       NaN       NaN     NaN
#  2019-01-30  0.264629       NaN       NaN     NaN
#  2019-01-31 -0.014452       NaN       NaN     NaN
#  2019-02-01 -0.292346       NaN       NaN     NaN
#  2019-02-04 -0.509505       NaN       NaN     NaN
#  2019-02-05 -0.758659       NaN       NaN     NaN
#  2019-02-06 -0.848264       NaN       NaN     NaN
#  2019-02-07 -0.860364       NaN -0.860364  valley
#  2019-02-08 -0.805623       NaN       NaN     NaN
#  2019-02-11 -0.704086       NaN       NaN     NaN
#  2019-02-12 -0.511732       NaN       NaN     NaN
#  2019-02-13 -0.308945 -0.308945       NaN    peak,
#  1:                Close     peaks   valleys      pv
#  Date
#  2019-01-16 -0.007587       NaN       NaN     NaN
#  2019-01-17  0.285784       NaN       NaN     NaN
#  2019-01-18  0.461763       NaN       NaN     NaN
#  2019-01-22  0.634364       NaN       NaN     NaN
#  2019-01-23  0.831003       NaN       NaN     NaN
#  2019-01-24  0.865560       NaN       NaN     NaN
#  2019-01-25  0.870664  0.870664       NaN    peak
#  2019-01-28  0.732702       NaN       NaN     NaN
#  2019-01-29  0.500443       NaN       NaN     NaN
#  2019-01-30  0.269671       NaN       NaN     NaN
#  2019-01-31  0.018461       NaN       NaN     NaN
#  2019-02-01 -0.274627       NaN       NaN     NaN
#  2019-02-04 -0.529347       NaN       NaN     NaN
#  2019-02-05 -0.682755       NaN       NaN     NaN
#  2019-02-06 -0.820001       NaN       NaN     NaN
#  2019-02-07 -0.873743       NaN -0.873743  valley
#  2019-02-08 -0.862397       NaN       NaN     NaN
#  2019-02-11 -0.685360       NaN       NaN     NaN
#  2019-02-12 -0.493650       NaN       NaN     NaN
#  2019-02-13 -0.249962       NaN       NaN     NaN
#  2019-02-14  0.016470       NaN       NaN     NaN
#  2019-02-15  0.283910       NaN       NaN     NaN
#  2019-02-19  0.510027       NaN       NaN     NaN
#  2019-02-20  0.753954       NaN       NaN     NaN
#  2019-02-21  0.857744       NaN       NaN     NaN
#  2019-02-22  0.864168  0.864168       NaN    peak
#  2019-02-25  0.812389       NaN       NaN     NaN
#  2019-02-26  0.713315       NaN       NaN     NaN
#  2019-02-27  0.535943       NaN       NaN     NaN
#  2019-02-28  0.304329       NaN  0.304329  valley,
#  2:                Close     peaks   valleys      pv
#  Date
#  2019-01-31  0.016467       NaN       NaN     NaN
#  2019-02-01 -0.283141       NaN       NaN     NaN
#  2019-02-04 -0.454210       NaN       NaN     NaN
#  2019-02-05 -0.642337       NaN       NaN     NaN
#  2019-02-06 -0.827303       NaN       NaN     NaN
#  2019-02-07 -0.854080       NaN       NaN     NaN
#  2019-02-08 -0.868122       NaN -0.868122  valley
#  2019-02-11 -0.729193       NaN       NaN     NaN
#  2019-02-12 -0.508064       NaN       NaN     NaN
#  2019-02-13 -0.262812       NaN       NaN     NaN
#  2019-02-14 -0.026416       NaN       NaN     NaN
#  2019-02-15  0.273487       NaN       NaN     NaN
#  2019-02-19  0.517942       NaN       NaN     NaN
#  2019-02-20  0.684688       NaN       NaN     NaN
#  2019-02-21  0.828749       NaN       NaN     NaN
#  2019-02-22  0.878905  0.878905       NaN    peak
#  2019-02-25  0.853729       NaN       NaN     NaN
#  2019-02-26  0.680173       NaN       NaN     NaN
#  2019-02-27  0.505070       NaN       NaN     NaN
#  2019-02-28  0.264629       NaN       NaN     NaN
#  2019-03-01 -0.014453       NaN       NaN     NaN
#  2019-03-04 -0.292347       NaN       NaN     NaN
#  2019-03-05 -0.509504       NaN       NaN     NaN
#  2019-03-06 -0.758660       NaN       NaN     NaN
#  2019-03-07 -0.848264       NaN       NaN     NaN
#  2019-03-08 -0.860361       NaN -0.860361  valley
#  2019-03-11 -0.805619       NaN       NaN     NaN
#  2019-03-12 -0.704084       NaN       NaN     NaN
#  2019-03-13 -0.511731       NaN       NaN     NaN
#  2019-03-14 -0.308947 -0.308947       NaN    peak,
#  3:                Close     peaks   valleys      pv
#  Date
#  2019-02-14 -0.007586       NaN       NaN     NaN
#  2019-02-15  0.285784       NaN       NaN     NaN
#  2019-02-19  0.461765       NaN       NaN     NaN
#  2019-02-20  0.634369       NaN       NaN     NaN
#  2019-02-21  0.831006       NaN       NaN     NaN
#  2019-02-22  0.865563       NaN       NaN     NaN
#  2019-02-25  0.870664  0.870664       NaN    peak
#  2019-02-26  0.732702       NaN       NaN     NaN
#  2019-02-27  0.500445       NaN       NaN     NaN
#  2019-02-28  0.269671       NaN       NaN     NaN
#  2019-03-01  0.018460       NaN       NaN     NaN
#  2019-03-04 -0.274627       NaN       NaN     NaN
#  2019-03-05 -0.529347       NaN       NaN     NaN
#  2019-03-06 -0.682757       NaN       NaN     NaN
#  2019-03-07 -0.820001       NaN       NaN     NaN
#  2019-03-08 -0.873744       NaN -0.873744  valley
#  2019-03-11 -0.862397       NaN       NaN     NaN
#  2019-03-12 -0.685362       NaN       NaN     NaN
#  2019-03-13 -0.493651       NaN       NaN     NaN
#  2019-03-14 -0.249962       NaN       NaN     NaN
#  2019-03-15  0.016469       NaN       NaN     NaN
#  2019-03-18  0.283910       NaN       NaN     NaN
#  2019-03-19  0.510028       NaN       NaN     NaN
#  2019-03-20  0.753953       NaN       NaN     NaN
#  2019-03-21  0.857744       NaN       NaN     NaN
#  2019-03-22  0.864170  0.864170       NaN    peak
#  2019-03-25  0.812392       NaN       NaN     NaN
#  2019-03-26  0.713316       NaN       NaN     NaN
#  2019-03-27  0.535944       NaN       NaN     NaN
#  2019-03-28  0.304328       NaN  0.304328  valley,
#  4:                Close     peaks   valleys      pv
#  Date
#  2019-03-01  0.016468       NaN       NaN     NaN
#  2019-03-04 -0.283141       NaN       NaN     NaN
#  2019-03-05 -0.454207       NaN       NaN     NaN
#  2019-03-06 -0.642331       NaN       NaN     NaN
#  2019-03-07 -0.827300       NaN       NaN     NaN
#  2019-03-08 -0.854078       NaN       NaN     NaN
#  2019-03-11 -0.868122       NaN -0.868122  valley
#  2019-03-12 -0.729192       NaN       NaN     NaN
#  2019-03-13 -0.508061       NaN       NaN     NaN
#  2019-03-14 -0.262812       NaN       NaN     NaN
#  2019-03-15 -0.026417       NaN       NaN     NaN
#  2019-03-18  0.273487       NaN       NaN     NaN
#  2019-03-19  0.517941       NaN       NaN     NaN
#  2019-03-20  0.684685       NaN       NaN     NaN
#  2019-03-21  0.828748       NaN       NaN     NaN
#  2019-03-22  0.878903  0.878903       NaN    peak
#  2019-03-25  0.853727       NaN       NaN     NaN
#  2019-03-26  0.680171       NaN       NaN     NaN
#  2019-03-27  0.505068       NaN       NaN     NaN
#  2019-03-28  0.264628       NaN       NaN     NaN
#  2019-03-29 -0.014455       NaN       NaN     NaN
#  2019-04-01 -0.292347       NaN       NaN     NaN
#  2019-04-02 -0.509503       NaN       NaN     NaN
#  2019-04-03 -0.758661       NaN       NaN     NaN
#  2019-04-04 -0.848263       NaN       NaN     NaN
#  2019-04-05 -0.860359       NaN -0.860359  valley
#  2019-04-08 -0.805616       NaN       NaN     NaN
#  2019-04-09 -0.704083       NaN       NaN     NaN
#  2019-04-10 -0.511730       NaN       NaN     NaN
#  2019-04-11 -0.308949 -0.308949       NaN    peak,
#  5:                Close     peaks   valleys      pv
#  Date
#  2019-03-15 -0.007586       NaN       NaN     NaN
#  2019-03-18  0.285784       NaN       NaN     NaN
#  2019-03-19  0.461767       NaN       NaN     NaN
#  2019-03-20  0.634375       NaN       NaN     NaN
#  2019-03-21  0.831009       NaN       NaN     NaN
#  2019-03-22  0.865565       NaN       NaN     NaN
#  2019-03-25  0.870664  0.870664       NaN    peak
#  2019-03-26  0.732702       NaN       NaN     NaN
#  2019-03-27  0.500448       NaN       NaN     NaN
#  2019-03-28  0.269671       NaN       NaN     NaN
#  2019-03-29  0.018460       NaN       NaN     NaN
#  2019-04-01 -0.274628       NaN       NaN     NaN
#  2019-04-02 -0.529347       NaN       NaN     NaN
#  2019-04-03 -0.682760       NaN       NaN     NaN
#  2019-04-04 -0.820001       NaN       NaN     NaN
#  2019-04-05 -0.873746       NaN -0.873746  valley
#  2019-04-08 -0.862398       NaN       NaN     NaN
#  2019-04-09 -0.685363       NaN       NaN     NaN
#  2019-04-10 -0.493652       NaN       NaN     NaN
#  2019-04-11 -0.249962       NaN       NaN     NaN
#  2019-04-12  0.016467       NaN       NaN     NaN
#  2019-04-15  0.283909       NaN       NaN     NaN
#  2019-04-16  0.510029       NaN       NaN     NaN
#  2019-04-17  0.753951       NaN       NaN     NaN
#  2019-04-18  0.857744       NaN       NaN     NaN
#  2019-04-22  0.864173  0.864173       NaN    peak
#  2019-04-23  0.812395       NaN       NaN     NaN
#  2019-04-24  0.713317       NaN       NaN     NaN
#  2019-04-25  0.535945       NaN       NaN     NaN
#  2019-04-26  0.304327       NaN  0.304327  valley,
#  6:                Close     peaks   valleys      pv
#  Date
#  2019-03-29  0.016469       NaN       NaN     NaN
#  2019-04-01 -0.283140       NaN       NaN     NaN
#  2019-04-02 -0.454204       NaN       NaN     NaN
#  2019-04-03 -0.642325       NaN       NaN     NaN
#  2019-04-04 -0.827296       NaN       NaN     NaN
#  2019-04-05 -0.854076       NaN       NaN     NaN
#  2019-04-08 -0.868122       NaN -0.868122  valley
#  2019-04-09 -0.729192       NaN       NaN     NaN
#  2019-04-10 -0.508058       NaN       NaN     NaN
#  2019-04-11 -0.262812       NaN       NaN     NaN
#  2019-04-12 -0.026418       NaN       NaN     NaN
#  2019-04-15  0.273487       NaN       NaN     NaN
#  2019-04-16  0.517941       NaN       NaN     NaN
#  2019-04-17  0.684682       NaN       NaN     NaN
#  2019-04-18  0.828747       NaN       NaN     NaN
#  2019-04-22  0.878901  0.878901       NaN    peak
#  2019-04-23  0.853726       NaN       NaN     NaN
#  2019-04-24  0.680170       NaN       NaN     NaN
#  2019-04-25  0.505066       NaN       NaN     NaN
#  2019-04-26  0.264628       NaN       NaN     NaN
#  2019-04-29 -0.014456       NaN       NaN     NaN
#  2019-04-30 -0.292347       NaN       NaN     NaN
#  2019-05-01 -0.509502       NaN       NaN     NaN
#  2019-05-02 -0.758662       NaN       NaN     NaN
#  2019-05-03 -0.848263       NaN       NaN     NaN
#  2019-05-06 -0.860356       NaN -0.860356  valley
#  2019-05-07 -0.805612       NaN       NaN     NaN
#  2019-05-08 -0.704081       NaN       NaN     NaN
#  2019-05-09 -0.511729       NaN       NaN     NaN
#  2019-05-10 -0.308951 -0.308951       NaN    peak,
#  7:                Close     peaks   valleys      pv
#  Date
#  2019-04-12 -0.007585       NaN       NaN     NaN
#  2019-04-15  0.285784       NaN       NaN     NaN
#  2019-04-16  0.461769       NaN       NaN     NaN
#  2019-04-17  0.634380       NaN       NaN     NaN
#  2019-04-18  0.831011       NaN       NaN     NaN
#  2019-04-22  0.865568       NaN       NaN     NaN
#  2019-04-23  0.870664  0.870664       NaN    peak
#  2019-04-24  0.732702       NaN       NaN     NaN
#  2019-04-25  0.500451       NaN       NaN     NaN
#  2019-04-26  0.269671       NaN       NaN     NaN
#  2019-04-29  0.018460       NaN       NaN     NaN
#  2019-04-30 -0.274628       NaN       NaN     NaN
#  2019-05-01 -0.529347       NaN       NaN     NaN
#  2019-05-02 -0.682762       NaN       NaN     NaN
#  2019-05-03 -0.820002       NaN       NaN     NaN
#  2019-05-06 -0.873747       NaN -0.873747  valley
#  2019-05-07 -0.862399       NaN       NaN     NaN
#  2019-05-08 -0.685364       NaN       NaN     NaN
#  2019-05-09 -0.493654       NaN       NaN     NaN
#  2019-05-10 -0.249962       NaN       NaN     NaN
#  2019-05-13  0.016466       NaN       NaN     NaN
#  2019-05-14  0.283909       NaN       NaN     NaN
#  2019-05-15  0.510030       NaN       NaN     NaN
#  2019-05-16  0.753951       NaN       NaN     NaN
#  2019-05-17  0.857743       NaN       NaN     NaN
#  2019-05-20  0.864175  0.864175       NaN    peak
#  2019-05-21  0.812397       NaN       NaN     NaN
#  2019-05-22  0.713318       NaN       NaN     NaN
#  2019-05-23  0.535945       NaN       NaN     NaN
#  2019-05-24  0.304325       NaN  0.304325  valley,
#  8:                Close     peaks   valleys      pv
#  Date
#  2019-04-29  0.016470       NaN       NaN     NaN
#  2019-04-30 -0.283140       NaN       NaN     NaN
#  2019-05-01 -0.454201       NaN       NaN     NaN
#  2019-05-02 -0.642318       NaN       NaN     NaN
#  2019-05-03 -0.827293       NaN       NaN     NaN
#  2019-05-06 -0.854074       NaN       NaN     NaN
#  2019-05-07 -0.868122       NaN -0.868122  valley
#  2019-05-08 -0.729191       NaN       NaN     NaN
#  2019-05-09 -0.508055       NaN       NaN     NaN
#  2019-05-10 -0.262812       NaN       NaN     NaN
#  2019-05-13 -0.026419       NaN       NaN     NaN
#  2019-05-14  0.273487       NaN       NaN     NaN
#  2019-05-15  0.517941       NaN       NaN     NaN
#  2019-05-16  0.684678       NaN       NaN     NaN
#  2019-05-17  0.828746       NaN       NaN     NaN
#  2019-05-20  0.878899  0.878899       NaN    peak
#  2019-05-21  0.853725       NaN       NaN     NaN
#  2019-05-22  0.680169       NaN       NaN     NaN
#  2019-05-23  0.505064       NaN       NaN     NaN
#  2019-05-24  0.264627       NaN       NaN     NaN
#  2019-05-28 -0.014458       NaN       NaN     NaN
#  2019-05-29 -0.292348       NaN       NaN     NaN
#  2019-05-30 -0.509501       NaN       NaN     NaN
#  2019-05-31 -0.758663       NaN       NaN     NaN
#  2019-06-03 -0.848262       NaN       NaN     NaN
#  2019-06-04 -0.860354       NaN -0.860354  valley
#  2019-06-05 -0.805609       NaN       NaN     NaN
#  2019-06-06 -0.704080       NaN       NaN     NaN
#  2019-06-07 -0.511728       NaN       NaN     NaN
#  2019-06-10 -0.308952 -0.308952       NaN    peak,
#  9:                Close     peaks   valleys      pv
#  Date
#  2019-05-13 -0.007585       NaN       NaN     NaN
#  2019-05-14  0.285784       NaN       NaN     NaN
#  2019-05-15  0.461772       NaN       NaN     NaN
#  2019-05-16  0.634386       NaN       NaN     NaN
#  2019-05-17  0.831014       NaN       NaN     NaN
#  2019-05-20  0.865570       NaN       NaN     NaN
#  2019-05-21  0.870664  0.870664       NaN    peak
#  2019-05-22  0.732702       NaN       NaN     NaN
#  2019-05-23  0.500454       NaN       NaN     NaN
#  2019-05-24  0.269670       NaN       NaN     NaN
#  2019-05-28  0.018459       NaN       NaN     NaN
#  2019-05-29 -0.274628       NaN       NaN     NaN
#  2019-05-30 -0.529347       NaN       NaN     NaN
#  2019-05-31 -0.682765       NaN       NaN     NaN
#  2019-06-03 -0.820002       NaN       NaN     NaN
#  2019-06-04 -0.873748       NaN -0.873748  valley
#  2019-06-05 -0.862399       NaN       NaN     NaN
#  2019-06-06 -0.685365       NaN       NaN     NaN
#  2019-06-07 -0.493655       NaN       NaN     NaN
#  2019-06-10 -0.249962       NaN       NaN     NaN
#  2019-06-11  0.016464       NaN       NaN     NaN
#  2019-06-12  0.283908       NaN       NaN     NaN
#  2019-06-13  0.510032       NaN       NaN     NaN
#  2019-06-14  0.753949       NaN       NaN     NaN
#  2019-06-17  0.857743       NaN       NaN     NaN
#  2019-06-18  0.864177  0.864177       NaN    peak
#  2019-06-19  0.812400       NaN       NaN     NaN
#  2019-06-20  0.713319       NaN       NaN     NaN
#  2019-06-21  0.535946       NaN       NaN     NaN
#  2019-06-24  0.304324       NaN  0.304324  valley}

# %%
def find_signal_lead_train_function(data, processed_signal):
    for p in processed_signal:
        data = test_data.loc[processed_signal[p].index[0]:processed_signal[p].index[-1]]
        processing_signal = processed_signal[p]
        p_data = pd.DataFrame(
            {'peaks': data['peaks'], 'count': range(len(data))})
        p_data = p_data.drop(p_data[p_data['peaks'].isna()].index)
        p_data_count = list(p_data['count'])
        p_signal = pd.DataFrame(
            {'peaks': processing_signal['peaks'], 'count': range(len(processing_signal))})
        p_signal = p_signal.drop(p_signal[p_signal['peaks'].isna()].index)
        p_signal_list = list(p_signal['count'])
        p_lead = []
        for i in range(0, len(p_signal_list)):
            temp = []
            temp_abs = []
            temp_2 = []
            for j in range(0, len(p_data_count)):
                temp.append((p_data_count[j] - p_signal_list[i]))
                temp_abs.append(abs(p_data_count[j] - p_signal_list[i]))
            for k in range(0, len(temp_abs)):
                if temp_abs[k] == min(temp_abs):
                    temp_2 = temp[k]
            p_lead.append(temp_2)
        p_signal['lead'] = p_lead

        v_data = pd.DataFrame(
            {'valleys': data['valleys'], 'count': range(len(data))})
        v_data = v_data.drop(v_data[v_data['valleys'].isna()].index)
        v_data_count = list(v_data['count'])
        v_signal = pd.DataFrame(
            {'valleys': processing_signal['valleys'], 'count': range(len(processing_signal))})
        v_signal = v_signal.drop(
            v_signal[v_signal['valleys'].isna()].index)
        v_signal_list = list(v_signal['count'])
        v_lead = []
        for i in range(0, len(v_signal_list)):
            temp = []
            temp_abs = []
            temp_2 = []
            for j in range(0, len(v_data_count)):
                temp.append((v_data_count[j] - v_signal_list[i]))
                temp_abs.append(abs(v_data_count[j] - v_signal_list[i]))
            for k in range(0, len(temp_abs)):
                if temp_abs[k] == min(temp_abs):
                    temp_2 = temp[k]
            v_lead.append(temp_2)
        v_signal['lead'] = v_lead

        processed_signal[p]['lead'] = pd.Series(dtype='float64')
        processed_signal[p]['lead'].loc[p_signal['lead'].index] = p_signal['lead']
        processed_signal[p]['lead'].loc[v_signal['lead'].index] = v_signal['lead']

# %%
find_signal_lead_train_function(test_data, processed_signal)

# %%
test_data
# Out:
#                    Open         High          Low     Close    Adj Close  \
# Date
# 2019-01-02  2476.959961  2519.489990  2467.469971 -0.305995  2510.030029
# 2019-01-03  2491.919922  2493.139893  2443.959961 -0.584763  2447.889893
# 2019-01-04  2474.330078  2538.070068  2474.330078 -0.805994  2531.939941
# 2019-01-07  2535.610107  2566.159912  2524.560059 -0.948033  2549.689941
# 2019-01-08  2568.110107  2579.820068  2547.560059 -0.996976  2574.409912
# ...                 ...          ...          ...       ...          ...
# 2019-06-24  2951.419922  2954.919922  2944.050049  0.003093  2945.350098
# 2019-06-25  2945.780029  2946.520020  2916.010010 -0.305923  2917.379883
# 2019-06-26  2926.070068  2932.590088  2912.989990 -0.584691  2913.780029
# 2019-06-27  2919.659912  2929.300049  2918.570068 -0.805922  2924.919922
# 2019-06-28  2932.939941  2943.979980  2929.050049 -0.947961  2941.760010
#
#                 Volume  peaks   valleys      pv
# Date
# 2019-01-02  3733160000    NaN       NaN     NaN
# 2019-01-03  3858830000    NaN       NaN     NaN
# 2019-01-04  4234140000    NaN       NaN     NaN
# 2019-01-07  4133120000    NaN       NaN     NaN
# 2019-01-08  4120060000    NaN -0.996976  valley
# ...                ...    ...       ...     ...
# 2019-06-24  3136960000    NaN       NaN     NaN
# 2019-06-25  3579430000    NaN       NaN     NaN
# 2019-06-26  3511350000    NaN       NaN     NaN
# 2019-06-27  3162500000    NaN       NaN     NaN
# 2019-06-28  5422650000    NaN -0.947961  valley
#
# [124 rows x 9 columns]

# %%
processed_signal
# Out:
# {0:                Close     peaks   valleys      pv  lead
#  Date
#  2019-01-02  0.016467       NaN       NaN     NaN   NaN
#  2019-01-03 -0.283141       NaN       NaN     NaN   NaN
#  2019-01-04 -0.454213       NaN       NaN     NaN   NaN
#  2019-01-07 -0.642344       NaN       NaN     NaN   NaN
#  2019-01-08 -0.827306       NaN       NaN     NaN   NaN
#  2019-01-09 -0.854082       NaN       NaN     NaN   NaN
#  2019-01-10 -0.868122       NaN -0.868122  valley  -2.0
#  2019-01-11 -0.729193       NaN       NaN     NaN   NaN
#  2019-01-14 -0.508068       NaN       NaN     NaN   NaN
#  2019-01-15 -0.262812       NaN       NaN     NaN   NaN
#  2019-01-16 -0.026415       NaN       NaN     NaN   NaN
#  2019-01-17  0.273488       NaN       NaN     NaN   NaN
#  2019-01-18  0.517942       NaN       NaN     NaN   NaN
#  2019-01-22  0.684691       NaN       NaN     NaN   NaN
#  2019-01-23  0.828750       NaN       NaN     NaN   NaN
#  2019-01-24  0.878907  0.878907       NaN    peak  -1.0
#  2019-01-25  0.853730       NaN       NaN     NaN   NaN
#  2019-01-28  0.680174       NaN       NaN     NaN   NaN
#  2019-01-29  0.505072       NaN       NaN     NaN   NaN
#  2019-01-30  0.264629       NaN       NaN     NaN   NaN
#  2019-01-31 -0.014452       NaN       NaN     NaN   NaN
#  2019-02-01 -0.292346       NaN       NaN     NaN   NaN
#  2019-02-04 -0.509505       NaN       NaN     NaN   NaN
#  2019-02-05 -0.758659       NaN       NaN     NaN   NaN
#  2019-02-06 -0.848264       NaN       NaN     NaN   NaN
#  2019-02-07 -0.860364       NaN -0.860364  valley  -1.0
#  2019-02-08 -0.805623       NaN       NaN     NaN   NaN
#  2019-02-11 -0.704086       NaN       NaN     NaN   NaN
#  2019-02-12 -0.511732       NaN       NaN     NaN   NaN
#  2019-02-13 -0.308945 -0.308945       NaN    peak -15.0,
#  1:                Close     peaks   valleys      pv  lead
#  Date
#  2019-01-16 -0.007587       NaN       NaN     NaN   NaN
#  2019-01-17  0.285784       NaN       NaN     NaN   NaN
#  2019-01-18  0.461763       NaN       NaN     NaN   NaN
#  2019-01-22  0.634364       NaN       NaN     NaN   NaN
#  2019-01-23  0.831003       NaN       NaN     NaN   NaN
#  2019-01-24  0.865560       NaN       NaN     NaN   NaN
#  2019-01-25  0.870664  0.870664       NaN    peak  -2.0
#  2019-01-28  0.732702       NaN       NaN     NaN   NaN
#  2019-01-29  0.500443       NaN       NaN     NaN   NaN
#  2019-01-30  0.269671       NaN       NaN     NaN   NaN
#  2019-01-31  0.018461       NaN       NaN     NaN   NaN
#  2019-02-01 -0.274627       NaN       NaN     NaN   NaN
#  2019-02-04 -0.529347       NaN       NaN     NaN   NaN
#  2019-02-05 -0.682755       NaN       NaN     NaN   NaN
#  2019-02-06 -0.820001       NaN       NaN     NaN   NaN
#  2019-02-07 -0.873743       NaN -0.873743  valley  -1.0
#  2019-02-08 -0.862397       NaN       NaN     NaN   NaN
#  2019-02-11 -0.685360       NaN       NaN     NaN   NaN
#  2019-02-12 -0.493650       NaN       NaN     NaN   NaN
#  2019-02-13 -0.249962       NaN       NaN     NaN   NaN
#  2019-02-14  0.016470       NaN       NaN     NaN   NaN
#  2019-02-15  0.283910       NaN       NaN     NaN   NaN
#  2019-02-19  0.510027       NaN       NaN     NaN   NaN
#  2019-02-20  0.753954       NaN       NaN     NaN   NaN
#  2019-02-21  0.857744       NaN       NaN     NaN   NaN
#  2019-02-22  0.864168  0.864168       NaN    peak  -1.0
#  2019-02-25  0.812389       NaN       NaN     NaN   NaN
#  2019-02-26  0.713315       NaN       NaN     NaN   NaN
#  2019-02-27  0.535943       NaN       NaN     NaN   NaN
#  2019-02-28  0.304329       NaN  0.304329  valley -15.0,
#  2:                Close     peaks   valleys      pv  lead
#  Date
#  2019-01-31  0.016467       NaN       NaN     NaN   NaN
#  2019-02-01 -0.283141       NaN       NaN     NaN   NaN
#  2019-02-04 -0.454210       NaN       NaN     NaN   NaN
#  2019-02-05 -0.642337       NaN       NaN     NaN   NaN
#  2019-02-06 -0.827303       NaN       NaN     NaN   NaN
#  2019-02-07 -0.854080       NaN       NaN     NaN   NaN
#  2019-02-08 -0.868122       NaN -0.868122  valley  -2.0
#  2019-02-11 -0.729193       NaN       NaN     NaN   NaN
#  2019-02-12 -0.508064       NaN       NaN     NaN   NaN
#  2019-02-13 -0.262812       NaN       NaN     NaN   NaN
#  2019-02-14 -0.026416       NaN       NaN     NaN   NaN
#  2019-02-15  0.273487       NaN       NaN     NaN   NaN
#  2019-02-19  0.517942       NaN       NaN     NaN   NaN
#  2019-02-20  0.684688       NaN       NaN     NaN   NaN
#  2019-02-21  0.828749       NaN       NaN     NaN   NaN
#  2019-02-22  0.878905  0.878905       NaN    peak  -1.0
#  2019-02-25  0.853729       NaN       NaN     NaN   NaN
#  2019-02-26  0.680173       NaN       NaN     NaN   NaN
#  2019-02-27  0.505070       NaN       NaN     NaN   NaN
#  2019-02-28  0.264629       NaN       NaN     NaN   NaN
#  2019-03-01 -0.014453       NaN       NaN     NaN   NaN
#  2019-03-04 -0.292347       NaN       NaN     NaN   NaN
#  2019-03-05 -0.509504       NaN       NaN     NaN   NaN
#  2019-03-06 -0.758660       NaN       NaN     NaN   NaN
#  2019-03-07 -0.848264       NaN       NaN     NaN   NaN
#  2019-03-08 -0.860361       NaN -0.860361  valley  -1.0
#  2019-03-11 -0.805619       NaN       NaN     NaN   NaN
#  2019-03-12 -0.704084       NaN       NaN     NaN   NaN
#  2019-03-13 -0.511731       NaN       NaN     NaN   NaN
#  2019-03-14 -0.308947 -0.308947       NaN    peak -15.0,
#  3:                Close     peaks   valleys      pv  lead
#  Date
#  2019-02-14 -0.007586       NaN       NaN     NaN   NaN
#  2019-02-15  0.285784       NaN       NaN     NaN   NaN
#  2019-02-19  0.461765       NaN       NaN     NaN   NaN
#  2019-02-20  0.634369       NaN       NaN     NaN   NaN
#  2019-02-21  0.831006       NaN       NaN     NaN   NaN
#  2019-02-22  0.865563       NaN       NaN     NaN   NaN
#  2019-02-25  0.870664  0.870664       NaN    peak  -2.0
#  2019-02-26  0.732702       NaN       NaN     NaN   NaN
#  2019-02-27  0.500445       NaN       NaN     NaN   NaN
#  2019-02-28  0.269671       NaN       NaN     NaN   NaN
#  2019-03-01  0.018460       NaN       NaN     NaN   NaN
#  2019-03-04 -0.274627       NaN       NaN     NaN   NaN
#  2019-03-05 -0.529347       NaN       NaN     NaN   NaN
#  2019-03-06 -0.682757       NaN       NaN     NaN   NaN
#  2019-03-07 -0.820001       NaN       NaN     NaN   NaN
#  2019-03-08 -0.873744       NaN -0.873744  valley  -1.0
#  2019-03-11 -0.862397       NaN       NaN     NaN   NaN
#  2019-03-12 -0.685362       NaN       NaN     NaN   NaN
#  2019-03-13 -0.493651       NaN       NaN     NaN   NaN
#  2019-03-14 -0.249962       NaN       NaN     NaN   NaN
#  2019-03-15  0.016469       NaN       NaN     NaN   NaN
#  2019-03-18  0.283910       NaN       NaN     NaN   NaN
#  2019-03-19  0.510028       NaN       NaN     NaN   NaN
#  2019-03-20  0.753953       NaN       NaN     NaN   NaN
#  2019-03-21  0.857744       NaN       NaN     NaN   NaN
#  2019-03-22  0.864170  0.864170       NaN    peak  -1.0
#  2019-03-25  0.812392       NaN       NaN     NaN   NaN
#  2019-03-26  0.713316       NaN       NaN     NaN   NaN
#  2019-03-27  0.535944       NaN       NaN     NaN   NaN
#  2019-03-28  0.304328       NaN  0.304328  valley -15.0,
#  4:                Close     peaks   valleys      pv  lead
#  Date
#  2019-03-01  0.016468       NaN       NaN     NaN   NaN
#  2019-03-04 -0.283141       NaN       NaN     NaN   NaN
#  2019-03-05 -0.454207       NaN       NaN     NaN   NaN
#  2019-03-06 -0.642331       NaN       NaN     NaN   NaN
#  2019-03-07 -0.827300       NaN       NaN     NaN   NaN
#  2019-03-08 -0.854078       NaN       NaN     NaN   NaN
#  2019-03-11 -0.868122       NaN -0.868122  valley  -2.0
#  2019-03-12 -0.729192       NaN       NaN     NaN   NaN
#  2019-03-13 -0.508061       NaN       NaN     NaN   NaN
#  2019-03-14 -0.262812       NaN       NaN     NaN   NaN
#  2019-03-15 -0.026417       NaN       NaN     NaN   NaN
#  2019-03-18  0.273487       NaN       NaN     NaN   NaN
#  2019-03-19  0.517941       NaN       NaN     NaN   NaN
#  2019-03-20  0.684685       NaN       NaN     NaN   NaN
#  2019-03-21  0.828748       NaN       NaN     NaN   NaN
#  2019-03-22  0.878903  0.878903       NaN    peak  -1.0
#  2019-03-25  0.853727       NaN       NaN     NaN   NaN
#  2019-03-26  0.680171       NaN       NaN     NaN   NaN
#  2019-03-27  0.505068       NaN       NaN     NaN   NaN
#  2019-03-28  0.264628       NaN       NaN     NaN   NaN
#  2019-03-29 -0.014455       NaN       NaN     NaN   NaN
#  2019-04-01 -0.292347       NaN       NaN     NaN   NaN
#  2019-04-02 -0.509503       NaN       NaN     NaN   NaN
#  2019-04-03 -0.758661       NaN       NaN     NaN   NaN
#  2019-04-04 -0.848263       NaN       NaN     NaN   NaN
#  2019-04-05 -0.860359       NaN -0.860359  valley  -1.0
#  2019-04-08 -0.805616       NaN       NaN     NaN   NaN
#  2019-04-09 -0.704083       NaN       NaN     NaN   NaN
#  2019-04-10 -0.511730       NaN       NaN     NaN   NaN
#  2019-04-11 -0.308949 -0.308949       NaN    peak -15.0,
#  5:                Close     peaks   valleys      pv  lead
#  Date
#  2019-03-15 -0.007586       NaN       NaN     NaN   NaN
#  2019-03-18  0.285784       NaN       NaN     NaN   NaN
#  2019-03-19  0.461767       NaN       NaN     NaN   NaN
#  2019-03-20  0.634375       NaN       NaN     NaN   NaN
#  2019-03-21  0.831009       NaN       NaN     NaN   NaN
#  2019-03-22  0.865565       NaN       NaN     NaN   NaN
#  2019-03-25  0.870664  0.870664       NaN    peak  -2.0
#  2019-03-26  0.732702       NaN       NaN     NaN   NaN
#  2019-03-27  0.500448       NaN       NaN     NaN   NaN
#  2019-03-28  0.269671       NaN       NaN     NaN   NaN
#  2019-03-29  0.018460       NaN       NaN     NaN   NaN
#  2019-04-01 -0.274628       NaN       NaN     NaN   NaN
#  2019-04-02 -0.529347       NaN       NaN     NaN   NaN
#  2019-04-03 -0.682760       NaN       NaN     NaN   NaN
#  2019-04-04 -0.820001       NaN       NaN     NaN   NaN
#  2019-04-05 -0.873746       NaN -0.873746  valley  -1.0
#  2019-04-08 -0.862398       NaN       NaN     NaN   NaN
#  2019-04-09 -0.685363       NaN       NaN     NaN   NaN
#  2019-04-10 -0.493652       NaN       NaN     NaN   NaN
#  2019-04-11 -0.249962       NaN       NaN     NaN   NaN
#  2019-04-12  0.016467       NaN       NaN     NaN   NaN
#  2019-04-15  0.283909       NaN       NaN     NaN   NaN
#  2019-04-16  0.510029       NaN       NaN     NaN   NaN
#  2019-04-17  0.753951       NaN       NaN     NaN   NaN
#  2019-04-18  0.857744       NaN       NaN     NaN   NaN
#  2019-04-22  0.864173  0.864173       NaN    peak  -1.0
#  2019-04-23  0.812395       NaN       NaN     NaN   NaN
#  2019-04-24  0.713317       NaN       NaN     NaN   NaN
#  2019-04-25  0.535945       NaN       NaN     NaN   NaN
#  2019-04-26  0.304327       NaN  0.304327  valley -15.0,
#  6:                Close     peaks   valleys      pv  lead
#  Date
#  2019-03-29  0.016469       NaN       NaN     NaN   NaN
#  2019-04-01 -0.283140       NaN       NaN     NaN   NaN
#  2019-04-02 -0.454204       NaN       NaN     NaN   NaN
#  2019-04-03 -0.642325       NaN       NaN     NaN   NaN
#  2019-04-04 -0.827296       NaN       NaN     NaN   NaN
#  2019-04-05 -0.854076       NaN       NaN     NaN   NaN
#  2019-04-08 -0.868122       NaN -0.868122  valley  -2.0
#  2019-04-09 -0.729192       NaN       NaN     NaN   NaN
#  2019-04-10 -0.508058       NaN       NaN     NaN   NaN
#  2019-04-11 -0.262812       NaN       NaN     NaN   NaN
#  2019-04-12 -0.026418       NaN       NaN     NaN   NaN
#  2019-04-15  0.273487       NaN       NaN     NaN   NaN
#  2019-04-16  0.517941       NaN       NaN     NaN   NaN
#  2019-04-17  0.684682       NaN       NaN     NaN   NaN
#  2019-04-18  0.828747       NaN       NaN     NaN   NaN
#  2019-04-22  0.878901  0.878901       NaN    peak  -1.0
#  2019-04-23  0.853726       NaN       NaN     NaN   NaN
#  2019-04-24  0.680170       NaN       NaN     NaN   NaN
#  2019-04-25  0.505066       NaN       NaN     NaN   NaN
#  2019-04-26  0.264628       NaN       NaN     NaN   NaN
#  2019-04-29 -0.014456       NaN       NaN     NaN   NaN
#  2019-04-30 -0.292347       NaN       NaN     NaN   NaN
#  2019-05-01 -0.509502       NaN       NaN     NaN   NaN
#  2019-05-02 -0.758662       NaN       NaN     NaN   NaN
#  2019-05-03 -0.848263       NaN       NaN     NaN   NaN
#  2019-05-06 -0.860356       NaN -0.860356  valley  -1.0
#  2019-05-07 -0.805612       NaN       NaN     NaN   NaN
#  2019-05-08 -0.704081       NaN       NaN     NaN   NaN
#  2019-05-09 -0.511729       NaN       NaN     NaN   NaN
#  2019-05-10 -0.308951 -0.308951       NaN    peak -15.0,
#  7:                Close     peaks   valleys      pv  lead
#  Date
#  2019-04-12 -0.007585       NaN       NaN     NaN   NaN
#  2019-04-15  0.285784       NaN       NaN     NaN   NaN
#  2019-04-16  0.461769       NaN       NaN     NaN   NaN
#  2019-04-17  0.634380       NaN       NaN     NaN   NaN
#  2019-04-18  0.831011       NaN       NaN     NaN   NaN
#  2019-04-22  0.865568       NaN       NaN     NaN   NaN
#  2019-04-23  0.870664  0.870664       NaN    peak  -2.0
#  2019-04-24  0.732702       NaN       NaN     NaN   NaN
#  2019-04-25  0.500451       NaN       NaN     NaN   NaN
#  2019-04-26  0.269671       NaN       NaN     NaN   NaN
#  2019-04-29  0.018460       NaN       NaN     NaN   NaN
#  2019-04-30 -0.274628       NaN       NaN     NaN   NaN
#  2019-05-01 -0.529347       NaN       NaN     NaN   NaN
#  2019-05-02 -0.682762       NaN       NaN     NaN   NaN
#  2019-05-03 -0.820002       NaN       NaN     NaN   NaN
#  2019-05-06 -0.873747       NaN -0.873747  valley  -1.0
#  2019-05-07 -0.862399       NaN       NaN     NaN   NaN
#  2019-05-08 -0.685364       NaN       NaN     NaN   NaN
#  2019-05-09 -0.493654       NaN       NaN     NaN   NaN
#  2019-05-10 -0.249962       NaN       NaN     NaN   NaN
#  2019-05-13  0.016466       NaN       NaN     NaN   NaN
#  2019-05-14  0.283909       NaN       NaN     NaN   NaN
#  2019-05-15  0.510030       NaN       NaN     NaN   NaN
#  2019-05-16  0.753951       NaN       NaN     NaN   NaN
#  2019-05-17  0.857743       NaN       NaN     NaN   NaN
#  2019-05-20  0.864175  0.864175       NaN    peak  -1.0
#  2019-05-21  0.812397       NaN       NaN     NaN   NaN
#  2019-05-22  0.713318       NaN       NaN     NaN   NaN
#  2019-05-23  0.535945       NaN       NaN     NaN   NaN
#  2019-05-24  0.304325       NaN  0.304325  valley -15.0,
#  8:                Close     peaks   valleys      pv  lead
#  Date
#  2019-04-29  0.016470       NaN       NaN     NaN   NaN
#  2019-04-30 -0.283140       NaN       NaN     NaN   NaN
#  2019-05-01 -0.454201       NaN       NaN     NaN   NaN
#  2019-05-02 -0.642318       NaN       NaN     NaN   NaN
#  2019-05-03 -0.827293       NaN       NaN     NaN   NaN
#  2019-05-06 -0.854074       NaN       NaN     NaN   NaN
#  2019-05-07 -0.868122       NaN -0.868122  valley  -2.0
#  2019-05-08 -0.729191       NaN       NaN     NaN   NaN
#  2019-05-09 -0.508055       NaN       NaN     NaN   NaN
#  2019-05-10 -0.262812       NaN       NaN     NaN   NaN
#  2019-05-13 -0.026419       NaN       NaN     NaN   NaN
#  2019-05-14  0.273487       NaN       NaN     NaN   NaN
#  2019-05-15  0.517941       NaN       NaN     NaN   NaN
#  2019-05-16  0.684678       NaN       NaN     NaN   NaN
#  2019-05-17  0.828746       NaN       NaN     NaN   NaN
#  2019-05-20  0.878899  0.878899       NaN    peak  -1.0
#  2019-05-21  0.853725       NaN       NaN     NaN   NaN
#  2019-05-22  0.680169       NaN       NaN     NaN   NaN
#  2019-05-23  0.505064       NaN       NaN     NaN   NaN
#  2019-05-24  0.264627       NaN       NaN     NaN   NaN
#  2019-05-28 -0.014458       NaN       NaN     NaN   NaN
#  2019-05-29 -0.292348       NaN       NaN     NaN   NaN
#  2019-05-30 -0.509501       NaN       NaN     NaN   NaN
#  2019-05-31 -0.758663       NaN       NaN     NaN   NaN
#  2019-06-03 -0.848262       NaN       NaN     NaN   NaN
#  2019-06-04 -0.860354       NaN -0.860354  valley  -1.0
#  2019-06-05 -0.805609       NaN       NaN     NaN   NaN
#  2019-06-06 -0.704080       NaN       NaN     NaN   NaN
#  2019-06-07 -0.511728       NaN       NaN     NaN   NaN
#  2019-06-10 -0.308952 -0.308952       NaN    peak -15.0,
#  9:                Close     peaks   valleys      pv  lead
#  Date
#  2019-05-13 -0.007585       NaN       NaN     NaN   NaN
#  2019-05-14  0.285784       NaN       NaN     NaN   NaN
#  2019-05-15  0.461772       NaN       NaN     NaN   NaN
#  2019-05-16  0.634386       NaN       NaN     NaN   NaN
#  2019-05-17  0.831014       NaN       NaN     NaN   NaN
#  2019-05-20  0.865570       NaN       NaN     NaN   NaN
#  2019-05-21  0.870664  0.870664       NaN    peak  -2.0
#  2019-05-22  0.732702       NaN       NaN     NaN   NaN
#  2019-05-23  0.500454       NaN       NaN     NaN   NaN
#  2019-05-24  0.269670       NaN       NaN     NaN   NaN
#  2019-05-28  0.018459       NaN       NaN     NaN   NaN
#  2019-05-29 -0.274628       NaN       NaN     NaN   NaN
#  2019-05-30 -0.529347       NaN       NaN     NaN   NaN
#  2019-05-31 -0.682765       NaN       NaN     NaN   NaN
#  2019-06-03 -0.820002       NaN       NaN     NaN   NaN
#  2019-06-04 -0.873748       NaN -0.873748  valley  -1.0
#  2019-06-05 -0.862399       NaN       NaN     NaN   NaN
#  2019-06-06 -0.685365       NaN       NaN     NaN   NaN
#  2019-06-07 -0.493655       NaN       NaN     NaN   NaN
#  2019-06-10 -0.249962       NaN       NaN     NaN   NaN
#  2019-06-11  0.016464       NaN       NaN     NaN   NaN
#  2019-06-12  0.283908       NaN       NaN     NaN   NaN
#  2019-06-13  0.510032       NaN       NaN     NaN   NaN
#  2019-06-14  0.753949       NaN       NaN     NaN   NaN
#  2019-06-17  0.857743       NaN       NaN     NaN   NaN
#  2019-06-18  0.864177  0.864177       NaN    peak  -1.0
#  2019-06-19  0.812400       NaN       NaN     NaN   NaN
#  2019-06-20  0.713319       NaN       NaN     NaN   NaN
#  2019-06-21  0.535946       NaN       NaN     NaN   NaN
#  2019-06-24  0.304324       NaN  0.304324  valley -15.0}

# %%
def get_first_lead_function(processed_signal):
    first_date = {}
    lead = {}
    pv = {}
    for i in processed_signal:
        temp = processed_signal[i].loc[list(
            processed_signal[i]['lead'].dropna().index)[0]]
        first_date[i] = list(processed_signal[i]
                             ['lead'].dropna().index)[0]
        lead[i] = temp['lead']
        pv[i] = temp['pv']
    return first_date, lead, pv

# %%
first_date, lead, pv = get_first_lead_function(processed_signal)

# %%
def built_result_table_function(processed_signal, lead, pv):
    result_table = pd.DataFrame(columns=[
        's_date', 't_date', 'lead', 'ans_date', 'pv'])
    for i in processed_signal:
        result_table.loc[i, 'lead'] = lead[i]
        result_table.loc[i, 'pv'] = pv[i]
        result_table.loc[i, 's_date'] = processed_signal[i].index[0]
    return result_table

# %%
result_table = built_result_table_function(processed_signal, lead, pv)
print(result_table)
# Out:
#                 s_date t_date lead ans_date      pv
# 0  2019-01-02 00:00:00    NaN -2.0      NaN  valley
# 1  2019-01-16 00:00:00    NaN -2.0      NaN    peak
# 2  2019-01-31 00:00:00    NaN -2.0      NaN  valley
# 3  2019-02-14 00:00:00    NaN -2.0      NaN    peak
# 4  2019-03-01 00:00:00    NaN -2.0      NaN  valley
# 5  2019-03-15 00:00:00    NaN -2.0      NaN    peak
# 6  2019-03-29 00:00:00    NaN -2.0      NaN  valley
# 7  2019-04-12 00:00:00    NaN -2.0      NaN    peak
# 8  2019-04-29 00:00:00    NaN -2.0      NaN  valley
# 9  2019-05-13 00:00:00    NaN -2.0      NaN    peak

# %%
def result_table_process_function(result_table, data, first_date):
    for i in result_table.index:
        t_date = first_date[i]
        result_table.loc[i, 't_date'] = t_date
        ans = data.iloc[int(data.index.get_loc(t_date) + result_table.loc[i, 'lead'])].name
        result_table.loc[i, 'ans_date'] = ans

# %%
result_table_process_function(result_table, test_data, first_date)

# %%
def compute_final_error_function(result_table):
    final_error = round(
        sum([abs(ele) for ele in result_table['lead']]) / len(result_table['lead']), 2)
    return final_error

# %%
final_error = compute_final_error_function(result_table)

# %%
def evaluate_model(processed_signal, test_data, first_date, lead, pv):
    result_table = built_result_table_function(processed_signal, lead, pv)
    result_table_process_function(result_table, test_data, first_date)
    final_error = compute_final_error_function(result_table)
    return result_table, final_error

# %%
result_table, final_error = evaluate_model(processed_signal, test_data, first_date, lead, pv)

# %%
print(result_table)
# Out:
#                 s_date               t_date lead             ans_date      pv
# 0  2019-01-02 00:00:00  2019-01-10 00:00:00 -2.0  2019-01-08 00:00:00  valley
# 1  2019-01-16 00:00:00  2019-01-25 00:00:00 -2.0  2019-01-23 00:00:00    peak
# 2  2019-01-31 00:00:00  2019-02-08 00:00:00 -2.0  2019-02-06 00:00:00  valley
# 3  2019-02-14 00:00:00  2019-02-25 00:00:00 -2.0  2019-02-21 00:00:00    peak
# 4  2019-03-01 00:00:00  2019-03-11 00:00:00 -2.0  2019-03-07 00:00:00  valley
# 5  2019-03-15 00:00:00  2019-03-25 00:00:00 -2.0  2019-03-21 00:00:00    peak
# 6  2019-03-29 00:00:00  2019-04-08 00:00:00 -2.0  2019-04-04 00:00:00  valley
# 7  2019-04-12 00:00:00  2019-04-23 00:00:00 -2.0  2019-04-18 00:00:00    peak
# 8  2019-04-29 00:00:00  2019-05-07 00:00:00 -2.0  2019-05-03 00:00:00  valley
# 9  2019-05-13 00:00:00  2019-05-21 00:00:00 -2.0  2019-05-17 00:00:00    peak

# %%
print(f'final_error = {final_error}')
# Out:
# final_error = 2.0

# %%
def draw_plot_result_table(test_data, all_data, result_table, pv_range):
    date_list = sorted(
        list(result_table['s_date']) + list(result_table['t_date']) + list(result_table['ans_date']))
    all_index = all_data.loc[date_list[0]:date_list[-1]].index
    fig, axes = plt.subplots(2, 1, figsize=(30, 8), sharex=True)
    test_data= test_data.drop(test_data[test_data.index > date_list[-1]].index)
    axes[0].plot(test_data.index, test_data['Close'], 'gray', label='data', linewidth=3)
    axes[0].plot(test_data.index, test_data['peaks'],
                '^', c='royalblue', label='peaks')
    axes[0].plot(test_data.index, test_data['valleys'], 'v',
                c='orangered', label='valleys')
    plot_model = pd.DataFrame(index=all_index, columns=[
                                's_date', 't_date', 'ans_date', 'lead', 'pv'])
    plot_model['s_date'].loc[result_table['s_date']] = True
    plot_model['t_date'].loc[result_table['t_date']] = True
    plot_model['lead'].loc[result_table['t_date']] = list(result_table['lead'])
    plot_model['pv'].loc[result_table['t_date']] = list(result_table['pv'])
    plot_model['ans_date'].loc[result_table['ans_date']] = True
    for i, label in enumerate(plot_model['lead']):
        if plot_model['pv'][i] == 'peak':
            # axes[0].plot(plot_data.index[i], plot_data['Close'].iloc[i], '|',
            #             c='red')
            axes[1].plot(plot_model.index[i], plot_model['lead'][i], '^',
                            c='royalblue')
            text = str(label)
            axes[1].annotate(text, (plot_model.index[i],
                                plot_model['lead'][i]), fontsize=14)
        elif plot_model['pv'][i] == 'valley':
            # axes[0].plot(plot_data.index[i], plot_data['Close'].iloc[i], '|',
            #             c='red')
            axes[1].plot(plot_model.index[i], plot_model['lead'][i], 'v',
                            c='orangered')
            text = str(label)
            axes[1].annotate(text, (plot_model.index[i],
                                plot_model['lead'][i]), fontsize=14)

    axes[0].set_ylabel("Stock price", fontsize=14)
    axes[0].grid(True)
    axes[1].grid(True)
    axes[1].set_ylabel("lead", fontsize=14)
    plt.show()

# %%
draw_plot_result_table(test_data, data, result_table, pv_range)
