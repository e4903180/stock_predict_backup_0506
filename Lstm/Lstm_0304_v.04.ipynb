# %% [markdown]
# <div align='center'><font size="5" color='#353B47'>Predicting Stock Prices</font></div>
# <div align='center'><font size="4" color="#353B47">How to use LSTMs</font></div>
# <br>
# <hr>

# %% [markdown]
# **<font color="blue" size="4">Context</font>**
#
# > This notebook aims at showing a short script on how to predict stock prices using a LSTM model. An introduction has been made about <a href="https://www.kaggle.com/bryanb/introduction-to-time-series-analysis/edit/run/53321733">Time Series Analysis</a>, if you haven't read it yet, do not hesitate to give a look

# %% [markdown]
# **<font color="blue" size="4">Reminder</font>**
#
# > A Time Series is a **time-indexed** series of data. In Finance, a time series tracks the movement of the chosen data points, such as a *security’s price*, over a specified period of time with data points recorded at **regular intervals**.

# %% [markdown]
# <img src="https://miro.medium.com/max/1400/1*NpT5pyemQQsGEHXbfS51Zw.png" width="500">

# %% [markdown]
# **<font color="blue" size="4">Why is it used for ?</font>**
#
# > Time series analysis can be useful to see how a given asset, security, or economic variable changes over time. It can also be used to examine how the changes associated with the chosen data point compare to shifts in other variables over the same time period.
# >
# > For example, suppose you wanted to analyze a time series of daily closing stock prices for a given stock over a period of one year. You would obtain a list of all the closing prices for the stock from each day for the past year and list them in chronological order.

# %% [markdown]
# ## <div id="summary">Summary</div>
#
# **<font size="2"><a href="#chap1">1. Import libraries</a></font>**
# **<br><font size="2"><a href="#chap2">2. Preprocessing</a></font>**
# **<br><font size="2"><a href="#chap3">3. Build LSTM model</a></font>**
# **<br><font size="2"><a href="#chap4">4. Training</a></font>**
# **<br><font size="2"><a href="#chap5">5. Predictions</a></font>**

# %% [markdown]
# # <div id="chap1">1. Import libraries

# %%
import numpy as np
import pandas as pd

import os
import matplotlib.pyplot as plt
# import pandas_datareader as web
import datetime as dt

from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
import yfinance as yf

# %% [markdown]
# **<font size="2"><a href="#summary">Back to summary</a></font>**
#
# ----

# %% [markdown]
# # <div id="chap2">2. Preprocessing

# %%
COMPANY = '^GSPC'

# %%
data = yf.download(COMPANY, start='2018-01-01', end='2022-01-01')
len(data)
# Out:
# [*********************100%***********************]  1 of 1 completed
# 1008

# %%
array_data = np.array(data['Close'])
n_data = array_data.size
time_data = np.arange(0, n_data)
Polynomial = np.polyfit(time_data, array_data, 1)
data_notrend = array_data - Polynomial[0] * time_data  # detrended x
data['Close'] = data_notrend

# %%
plt.figure(figsize=(20, 8))
plt.plot(data['Close'], 'black', label=f"Actual {COMPANY} price")
plt.title(f"{COMPANY} share price, data")
plt.xlabel("time")
plt.ylabel(f"{COMPANY} share price")
plt.legend()
plt.show()

# %%
train_data = data[0:400]
valid_data = data[400:800]
test_data = data[800:1000]

# %%
plt.figure(figsize=(20, 8))
plt.plot(train_data['Close'], 'black', label=f"Actual {COMPANY} price")
plt.title(f"{COMPANY} share price, train")
plt.xlabel("time")
plt.ylabel(f"{COMPANY} share price")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.plot(valid_data['Close'], 'black', label=f"Actual {COMPANY} price")
plt.title(f"{COMPANY} share price, valid")
plt.xlabel("time")
plt.ylabel(f"{COMPANY} share price")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.plot(test_data['Close'], 'black', label=f"Actual {COMPANY} price")
plt.title(f"{COMPANY} share price, test")
plt.xlabel("time")
plt.ylabel(f"{COMPANY} share price")
plt.legend()
plt.show()

# %%
# Normalize data
scaler = MinMaxScaler(feature_range=(-1,1))
scaled_data = scaler.fit_transform(train_data['Close'].values.reshape(-1,1))

# %%
# how many days do i want to base my predictions on ?
prediction_days = 250

x_train = []
y_train = []

for x in range(prediction_days, len(scaled_data)):
    x_train.append(scaled_data[x - prediction_days:x, 0])
    y_train.append(scaled_data[x, 0])
    
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %% [markdown]
# **<font size="2"><a href="#summary">Back to summary</a></font>**
#
# ----

# %% [markdown]
# # <div id="chap3">3. Build LSTM model

# %% [markdown]
# **<font color="blue" size="4">What is a LSTM ?</font>**
#
# > Long Short Term Memory networks – usually just called “LSTMs” – are a special kind of RNN, capable of learning long-term dependencies. Introduced by Hochreiter & Schmidhuber (1997), and were refined and popularized by many people in following work. They work tremendously well on a large variety of problems, and are now widely used.
# >
# > LSTMs are explicitly designed to avoid the long-term dependency problem. Remembering information for long periods of time is practically their default behavior, not something they struggle to learn!
# >
# > All recurrent neural networks have the form of a chain of repeating modules of neural network.

# %% [markdown]
# You can find more details here: http://colah.github.io/posts/2015-08-Understanding-LSTMs/

# %%
def LSTM_model():
    
    model = Sequential()
    
    model.add(LSTM(units = 50, return_sequences = True, input_shape = (x_train.shape[1],1)))
    model.add(Dropout(0.2))

    model.add(LSTM(units = 50, return_sequences = True))
    model.add(Dropout(0.2))

    model.add(LSTM(units = 50))
    model.add(Dropout(0.2))
    
    model.add(Dense(units=1))
    
    return model

# %% [markdown]
# **<font size="2"><a href="#summary">Back to summary</a></font>**
#
# ----

# %% [markdown]
# # <div id="chap4">4. Training

# %%
# model = LSTM_model()
# model.summary()
# model.compile(optimizer='adam', loss='mean_squared_error')

# # Define callbacks
# # Save weights only for best model
# checkpointer = ModelCheckpoint(filepath = 'weights_best.hdf5', verbose = 2, save_best_only = True)
# earlystopper = EarlyStopping(monitor = 'val_loss', patience = 5, verbose = 2)

# history = model.fit(x_train, y_train, epochs=25, batch_size = 32, callbacks = [checkpointer, earlystopper], validation_split = 0.2)

# # plot loss curves
# plt.plot(history.history['loss'], label='train')
# plt.plot(history.history['val_loss'], label='validation')
# plt.legend()
# plt.show()

# %%
model = LSTM_model()
model.summary()
model.compile(optimizer='adam', 
              loss='mean_squared_error')
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 250, 50)           10400
#
#  dropout (Dropout)           (None, 250, 50)           0
#
#  lstm_1 (LSTM)               (None, 250, 50)           20200
#
#  dropout_1 (Dropout)         (None, 250, 50)           0
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dropout_2 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
# # Define callbacks

# # Save weights only for best model
# checkpointer = ModelCheckpoint(filepath = 'weights_best.hdf5', 
#                                verbose = 2, 
#                                save_best_only = True)

# model.fit(x_train, 
#           y_train, 
#           epochs=25, 
#           batch_size = 32,
#           callbacks = [checkpointer])

# %%
# Define callbacks
# Save weights only for best model
checkpointer = ModelCheckpoint(filepath = 'weights_best.hdf5', verbose = 2, save_best_only = True)
earlystopper = EarlyStopping(monitor = 'val_loss', patience = 5, verbose = 2)

history = model.fit(x_train, y_train, epochs=25, batch_size = 32, callbacks = [checkpointer, earlystopper], validation_split = 0.2)
# Out:
# Epoch 1/25
# 4/4 [==============================] - ETA: 0s - loss: 0.0957
# Epoch 1: val_loss improved from inf to 0.01004, saving model to weights_best.hdf5
# 4/4 [==============================] - 9s 887ms/step - loss: 0.0957 - val_loss: 0.0100
# Epoch 2/25
# 4/4 [==============================] - ETA: 0s - loss: 0.0285
# Epoch 2: val_loss did not improve from 0.01004
# 4/4 [==============================] - 2s 395ms/step - loss: 0.0285 - val_loss: 0.0350
# Epoch 3/25
# 4/4 [==============================] - ETA: 0s - loss: 0.0216
# Epoch 3: val_loss improved from 0.01004 to 0.00816, saving model to weights_best.hdf5
# 4/4 [==============================] - 2s 419ms/step - loss: 0.0216 - val_loss: 0.0082
# Epoch 4/25
# 4/4 [==============================] - ETA: 0s - loss: 0.0207
# Epoch 4: val_loss did not improve from 0.00816
# 4/4 [==============================] - 2s 393ms/step - loss: 0.0207 - val_loss: 0.0097
# Epoch 5/25
# 4/4 [==============================] - ETA: 0s - loss: 0.0184
# Epoch 5: val_loss improved from 0.00816 to 0.00768, saving model to weights_best.hdf5
# 4/4 [==============================] - 2s 400ms/step - loss: 0.0184 - val_loss: 0.0077
# Epoch 6/25
# 4/4 [==============================] - ETA: 0s - loss: 0.0127
# Epoch 6: val_loss did not improve from 0.00768
# 4/4 [==============================] - 2s 390ms/step - loss: 0.0127 - val_loss: 0.0115
# Epoch 7/25
# 4/4 [==============================] - ETA: 0s - loss: 0.0125
# Epoch 7: val_loss did not improve from 0.00768
# 4/4 [==============================] - 1s 376ms/step - loss: 0.0125 - val_loss: 0.0119
# Epoch 8/25
# 4/4 [==============================] - ETA: 0s - loss: 0.0122
# Epoch 8: val_loss did not improve from 0.00768
# 4/4 [==============================] - 2s 391ms/step - loss: 0.0122 - val_loss: 0.0078
# Epoch 9/25
# 4/4 [==============================] - ETA: 0s - loss: 0.0101
# Epoch 9: val_loss improved from 0.00768 to 0.00728, saving model to weights_best.hdf5
# 4/4 [==============================] - 2s 426ms/step - loss: 0.0101 - val_loss: 0.0073
# Epoch 10/25
# 4/4 [==============================] - ETA: 0s - loss: 0.0102
# Epoch 10: val_loss did not improve from 0.00728
# 4/4 [==============================] - 2s 385ms/step - loss: 0.0102 - val_loss: 0.0073
# Epoch 11/25
# 4/4 [==============================] - ETA: 0s - loss: 0.0115
# Epoch 11: val_loss did not improve from 0.00728
# 4/4 [==============================] - 2s 397ms/step - loss: 0.0115 - val_loss: 0.0088
# Epoch 12/25
# 4/4 [==============================] - ETA: 0s - loss: 0.0095
# Epoch 12: val_loss did not improve from 0.00728
# 4/4 [==============================] - 2s 393ms/step - loss: 0.0095 - val_loss: 0.0077
# Epoch 13/25
# 4/4 [==============================] - ETA: 0s - loss: 0.0085
# Epoch 13: val_loss improved from 0.00728 to 0.00683, saving model to weights_best.hdf5
# 4/4 [==============================] - 2s 396ms/step - loss: 0.0085 - val_loss: 0.0068
# Epoch 14/25
# 4/4 [==============================] - ETA: 0s - loss: 0.0086
# Epoch 14: val_loss improved from 0.00683 to 0.00672, saving model to weights_best.hdf5
# 4/4 [==============================] - 2s 402ms/step - loss: 0.0086 - val_loss: 0.0067
# Epoch 15/25
# 4/4 [==============================] - ETA: 0s - loss: 0.0077
# Epoch 15: val_loss did not improve from 0.00672
# 4/4 [==============================] - 2s 390ms/step - loss: 0.0077 - val_loss: 0.0069
# Epoch 16/25
# 4/4 [==============================] - ETA: 0s - loss: 0.0083
# Epoch 16: val_loss improved from 0.00672 to 0.00643, saving model to weights_best.hdf5
# 4/4 [==============================] - 2s 392ms/step - loss: 0.0083 - val_loss: 0.0064
# Epoch 17/25
# 4/4 [==============================] - ETA: 0s - loss: 0.0079
# Epoch 17: val_loss did not improve from 0.00643
# 4/4 [==============================] - 2s 396ms/step - loss: 0.0079 - val_loss: 0.0066
# Epoch 18/25
# 4/4 [==============================] - ETA: 0s - loss: 0.0082
# Epoch 18: val_loss improved from 0.00643 to 0.00633, saving model to weights_best.hdf5
# 4/4 [==============================] - 2s 425ms/step - loss: 0.0082 - val_loss: 0.0063
# Epoch 19/25
# 4/4 [==============================] - ETA: 0s - loss: 0.0069
# Epoch 19: val_loss improved from 0.00633 to 0.00617, saving model to weights_best.hdf5
# 4/4 [==============================] - 2s 389ms/step - loss: 0.0069 - val_loss: 0.0062
# Epoch 20/25
# 4/4 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 20: val_loss improved from 0.00617 to 0.00612, saving model to weights_best.hdf5
# 4/4 [==============================] - 2s 396ms/step - loss: 0.0071 - val_loss: 0.0061
# Epoch 21/25
# 4/4 [==============================] - ETA: 0s - loss: 0.0076
# Epoch 21: val_loss did not improve from 0.00612
# 4/4 [==============================] - 2s 394ms/step - loss: 0.0076 - val_loss: 0.0064
# Epoch 22/25
# 4/4 [==============================] - ETA: 0s - loss: 0.0076
# Epoch 22: val_loss did not improve from 0.00612
# 4/4 [==============================] - 2s 392ms/step - loss: 0.0076 - val_loss: 0.0061
# Epoch 23/25
# 4/4 [==============================] - ETA: 0s - loss: 0.0062
# Epoch 23: val_loss did not improve from 0.00612
# 4/4 [==============================] - 2s 397ms/step - loss: 0.0062 - val_loss: 0.0062
# Epoch 24/25
# 4/4 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 24: val_loss did not improve from 0.00612
# 4/4 [==============================] - 2s 385ms/step - loss: 0.0066 - val_loss: 0.0062
# Epoch 25/25
# 4/4 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 25: val_loss did not improve from 0.00612
# 4/4 [==============================] - 2s 399ms/step - loss: 0.0066 - val_loss: 0.0064
# Epoch 25: early stopping

# %%
# Loss
fig, ax = plt.subplots(figsize=(8,4))
plt.title('loss')
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss', linestyle='--')
plt.legend()
plt.show()

# %% [markdown]
# **<font size="2"><a href="#summary">Back to summary</a></font>**
#
# ----

# %% [markdown]
# # <div id="chap5">5. Predictions

# %%
# test model accuracy on existing data

actual_prices = valid_data['Close'].values
total_dataset = pd.concat((train_data['Close'], valid_data['Close']), axis=0)
model_inputs = total_dataset[len(total_dataset) - len(valid_data) - prediction_days:].values
model_inputs = model_inputs.reshape(-1,1)
model_inputs = scaler.transform(model_inputs)

# %%
x_test = []
for x in range(prediction_days, len(model_inputs)):
    x_test.append(model_inputs[x-prediction_days:x, 0])

x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1] ,1))

predicted_prices = model.predict(x_test)
predicted_prices = scaler.inverse_transform(predicted_prices)
# Out:
# 13/13 [==============================] - 3s 120ms/step

# %%
plt.figure(figsize=(20, 8))
plt.plot(actual_prices, color='black', label=f"Actual {COMPANY} price")
plt.plot(predicted_prices, color= 'green', label=f"predicted {COMPANY} price")
plt.title(f"{COMPANY} share price")
plt.xlabel("time")
plt.ylabel(f"{COMPANY} share price")
plt.legend()
plt.show()

# %%
# # predicting next day
# real_data = [model_inputs[len(model_inputs)+1 - prediction_days:len(model_inputs+1),0]]
# real_data = np.array(real_data)
# real_data = np.reshape(real_data, (real_data.shape[0], real_data.shape[1], 1))

# %%
# prediction = model.predict(real_data)
# prediction = scaler.inverse_transform(prediction)
# print(f"prediction: {prediction}")

# %%
# predicting next 10 days
real_data = [model_inputs[len(model_inputs) - prediction_days:len(model_inputs), 0]]
real_data = np.array(real_data)
real_data = np.reshape(real_data, (real_data.shape[0], real_data.shape[1], 1))

# %%
predictions = []
for i in range(100):
    prediction = model.predict(real_data)
    prediction = scaler.inverse_transform(prediction)
    predictions.append(prediction)
    real_data = np.append(real_data[:, 1:, :], np.expand_dims(prediction, axis=1), axis=1)


print(f"predictions: {predictions}")
# Out:
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 92ms/step
# predictions: [array([[2262.0586]], dtype=float32), array([[2291.5168]], dtype=float32), array([[2341.5945]], dtype=float32), array([[2398.6394]], dtype=float32), array([[2454.136]], dtype=float32), array([[2503.7827]], dtype=float32), array([[2545.983]], dtype=float32), array([[2580.6409]], dtype=float32), array([[2608.3877]], dtype=float32), array([[2630.1396]], dtype=float32), array([[2646.8665]], dtype=float32), array([[2659.4812]], dtype=float32), array([[2668.7944]], dtype=float32), array([[2675.4998]], dtype=float32), array([[2680.1787]], dtype=float32), array([[2683.3088]], dtype=float32), array([[2685.2764]], dtype=float32), array([[2686.3901]], dtype=float32), array([[2686.8926]], dtype=float32), array([[2686.9705]], dtype=float32), array([[2686.7678]], dtype=float32), array([[2686.3906]], dtype=float32), array([[2685.9177]], dtype=float32), array([[2685.4045]], dtype=float32), array([[2684.8896]], dtype=float32), array([[2684.3987]], dtype=float32), array([[2683.9465]], dtype=float32), array([[2683.5425]], dtype=float32), array([[2683.189]], dtype=float32), array([[2682.886]], dtype=float32), array([[2682.6313]], dtype=float32), array([[2682.4202]], dtype=float32), array([[2682.249]], dtype=float32), array([[2682.1118]], dtype=float32), array([[2682.0042]], dtype=float32), array([[2681.9214]], dtype=float32), array([[2681.8596]], dtype=float32), array([[2681.8145]], dtype=float32), array([[2681.783]], dtype=float32), array([[2681.762]], dtype=float32), array([[2681.7498]], dtype=float32), array([[2681.744]], dtype=float32), array([[2681.7427]], dtype=float32), array([[2681.7449]], dtype=float32), array([[2681.7498]], dtype=float32), array([[2681.756]], dtype=float32), array([[2681.7637]], dtype=float32), array([[2681.7715]], dtype=float32), array([[2681.7795]], dtype=float32), array([[2681.7878]], dtype=float32), array([[2681.7957]], dtype=float32), array([[2681.8035]], dtype=float32), array([[2681.8108]], dtype=float32), array([[2681.8176]], dtype=float32), array([[2681.8242]], dtype=float32), array([[2681.8303]], dtype=float32), array([[2681.8362]], dtype=float32), array([[2681.8416]], dtype=float32), array([[2681.847]], dtype=float32), array([[2681.8516]], dtype=float32), array([[2681.8562]], dtype=float32), array([[2681.8606]], dtype=float32), array([[2681.865]], dtype=float32), array([[2681.869]], dtype=float32), array([[2681.873]], dtype=float32), array([[2681.877]], dtype=float32), array([[2681.8809]], dtype=float32), array([[2681.8845]], dtype=float32), array([[2681.8882]], dtype=float32), array([[2681.8916]], dtype=float32), array([[2681.8953]], dtype=float32), array([[2681.8987]], dtype=float32), array([[2681.9023]], dtype=float32), array([[2681.9058]], dtype=float32), array([[2681.9092]], dtype=float32), array([[2681.9124]], dtype=float32), array([[2681.9158]], dtype=float32), array([[2681.9192]], dtype=float32), array([[2681.9226]], dtype=float32), array([[2681.926]], dtype=float32), array([[2681.9292]], dtype=float32), array([[2681.9326]], dtype=float32), array([[2681.9358]], dtype=float32), array([[2681.9392]], dtype=float32), array([[2681.9424]], dtype=float32), array([[2681.9456]], dtype=float32), array([[2681.9492]], dtype=float32), array([[2681.9524]], dtype=float32), array([[2681.9556]], dtype=float32), array([[2681.9587]], dtype=float32), array([[2681.9622]], dtype=float32), array([[2681.9653]], dtype=float32), array([[2681.9685]], dtype=float32), array([[2681.972]], dtype=float32), array([[2681.9753]], dtype=float32), array([[2681.9788]], dtype=float32), array([[2681.982]], dtype=float32), array([[2681.9849]], dtype=float32), array([[2681.9883]], dtype=float32), array([[2681.9917]], dtype=float32)]

# %%
len(test_data['Close'])
# Out:
# 200

# %%
import matplotlib.pyplot as plt

# 將預測結果轉換成numpy array並展平
predictions = np.array(predictions).flatten()

# 畫出實際價格和預測價格的曲線
plt.figure(figsize=(20, 8))
plt.plot(range(len(actual_prices), len(actual_prices)+len(test_data['Close'])), test_data['Close'])
plt.plot(range(0, len(actual_prices)), actual_prices)
plt.plot(range(len(actual_prices), len(actual_prices)+len(predictions)), predictions)
plt.xlabel("Day")
plt.ylabel("Price")
plt.legend(["true_data", "Actual Price", "Predicted Price"])
plt.show()

# %%
import matplotlib.pyplot as plt

# 將預測結果轉換成numpy array並展平
predictions = np.array(predictions).flatten()

# 畫出實際價格和預測價格的曲線
plt.plot(range(len(actual_prices), len(actual_prices)+len(test_data['Close'])), test_data['Close'])

# plt.plot(range(0, len(actual_prices)), actual_prices)
plt.plot(range(len(actual_prices), len(actual_prices)+len(predictions)), predictions)
plt.xlabel("Day")
plt.ylabel("Price")
plt.legend(["true_data", "Predicted Price"])
plt.show()

# %% [markdown]
# **<font size="2"><a href="#summary">Back to summary</a></font>**
#
# ----

# %% [markdown]
# # References
#
# * <a href = 'https://www.kaggle.com/bryanb/introduction-to-time-series-analysis/edit/run/53321733'>My notebook on Time series analysis</a>
# * <a href = 'http://colah.github.io/posts/2015-08-Understanding-LSTMs/'>LSTM Explanations</a>
# * <a href = 'https://www.kaggle.com/datasets/bryanb/cac40-stocks-dataset'>CAC 40 dataset</a>

# %% [markdown]
# <hr>
# <br>
# <div align='justify'><font color="#353B47" size="4">Thank you for taking the time to read this notebook. I hope that I was able to answer your questions or your curiosity and that it was quite understandable. <u>any constructive comments are welcome</u>. They help me progress and motivate me to share better quality content. I am above all a passionate person who tries to advance my knowledge but also that of others. If you liked it, feel free to <u>upvote and share my work.</u> </font></div>
# <br>
# <div align='center'><font color="#353B47" size="3">Thank you and may passion guide you.</font></div>
