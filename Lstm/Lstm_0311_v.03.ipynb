# %% [markdown]
# <div align='center'><font size="5" color='#353B47'>Predicting Stock Prices</font></div>
# <div align='center'><font size="4" color="#353B47">How to use LSTMs</font></div>
# <br>
# <hr>

# %% [markdown]
# **<font color="blue" size="4">Context</font>**
#
# > This notebook aims at showing a short script on how to predict stock prices using a LSTM model. An introduction has been made about <a href="https://www.kaggle.com/bryanb/introduction-to-time-series-analysis/edit/run/53321733">Time Series Analysis</a>, if you haven't read it yet, do not hesitate to give a look

# %% [markdown]
# **<font color="blue" size="4">Reminder</font>**
#
# > A Time Series is a **time-indexed** series of data. In Finance, a time series tracks the movement of the chosen data points, such as a *security's price*, over a specified period of time with data points recorded at **regular intervals**.

# %% [markdown]
# <img src="https://miro.medium.com/max/1400/1*NpT5pyemQQsGEHXbfS51Zw.png" width="500">

# %% [markdown]
# **<font color="blue" size="4">Why is it used for ?</font>**
#
# > Time series analysis can be useful to see how a given asset, security, or economic variable changes over time. It can also be used to examine how the changes associated with the chosen data point compare to shifts in other variables over the same time period.
# >
# > For example, suppose you wanted to analyze a time series of daily closing stock prices for a given stock over a period of one year. You would obtain a list of all the closing prices for the stock from each day for the past year and list them in chronological order.

# %% [markdown]
# ## <div id="summary">Summary</div>
#
# **<font size="2"><a href="#chap1">1. Import libraries</a></font>**
# **<br><font size="2"><a href="#chap2">2. Preprocessing</a></font>**
# **<br><font size="2"><a href="#chap3">3. Build LSTM model</a></font>**
# **<br><font size="2"><a href="#chap4">4. Training</a></font>**
# **<br><font size="2"><a href="#chap5">5. Predictions</a></font>**

# %% [markdown]
# # <div id="chap1">1. Import libraries

# %%
import numpy as np
import pandas as pd

import os
import matplotlib.pyplot as plt
# import pandas_datareader as web
import datetime as dt

from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
import yfinance as yf

# %% [markdown]
# **<font size="2"><a href="#summary">Back to summary</a></font>**
#
# ----

# %% [markdown]
# # <div id="chap2">2. Preprocessing

# %%
COMPANY = '^GSPC'

# %%
data = yf.download(COMPANY, start='2020-01-01', end='2022-01-01')
x = data["Close"]
for i in range(0, len(data)):
    # print(i%2)
    if i % 10 >= 5:
        x.iloc[i] = -1
    else:
        x.iloc[i] = 1
data['Close'] = x
plt.figure(figsize=(20, 8))
plt.plot(data['Close'], 'black')
len(data)
# Out:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\e4903\AppData\Local\Temp\ipykernel_7776\227137626.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x.iloc[i] = 1
# C:\Users\e4903\AppData\Local\Temp\ipykernel_7776\227137626.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x.iloc[i] = -1
# 505

# %%
# array_data = np.array(data['Close'])
# n_data = array_data.size
# time_data = np.arange(0, n_data)
# Polynomial = np.polyfit(time_data, array_data, 1)
# data_notrend = array_data - Polynomial[0] * time_data  # detrended x
# data['Close'] = data_notrend

# %%
plt.figure(figsize=(20, 8))
plt.plot(data['Close'], 'black', label=f"Actual {COMPANY} price")
plt.title(f"{COMPANY} share price, data")
plt.xlabel("time")
plt.ylabel(f"{COMPANY} share price")
plt.legend()
plt.show()

# %%
import math
math.ceil(len(data)*0.8)
# Out:
# 404

# %%
train_data = data[0:math.ceil(len(data)*0.8)]
print(len(train_data))
test_data = data[math.ceil(len(data)*0.8):]
print(len(test_data))
# Out:
# 404
# 101

# %%
plt.figure(figsize=(20, 8))
plt.plot(train_data['Close'], 'black', label=f"Actual {COMPANY} price")
plt.title(f"{COMPANY} share price, train")
plt.xlabel("time")
plt.ylabel(f"{COMPANY} share price")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.plot(test_data['Close'], 'black', label=f"Actual {COMPANY} price")
plt.title(f"{COMPANY} share price, test")
plt.xlabel("time")
plt.ylabel(f"{COMPANY} share price")
plt.legend()
plt.show()

# %%
# Normalize data
scaler = MinMaxScaler(feature_range=(-1,1))
scaled_data = scaler.fit_transform(train_data['Close'].values.reshape(-1,1))

# %%
plt.plot(scaled_data)

# %%
# how many days do i want to base my predictions on ?
base_day = 30
prediction_day = 10
x_train = []
y_train = []
# 從base_day開始，往前提取base_day天的數據，作為輸入變量x_train，並將當前價格作為輸出變量y_train
for x in range(base_day+prediction_day, len(scaled_data)):
    x_train.append(scaled_data[x-base_day-prediction_day:x-prediction_day, 0])
    y_train.append(scaled_data[x-prediction_day:x, 0])
    
x_train, y_train = np.array(x_train), np.array(y_train)

# # 將x_train數組的形狀轉換為（樣本數，天數，特徵數）的形式，這裡的特徵數為1
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %% [markdown]
# **<font size="2"><a href="#summary">Back to summary</a></font>**
#
# ----

# %% [markdown]
# # <div id="chap3">3. Build LSTM model

# %% [markdown]
# **<font color="blue" size="4">What is a LSTM ?</font>**
#
# > Long Short Term Memory networks – usually just called “LSTMs” – are a special kind of RNN, capable of learning long-term dependencies. Introduced by Hochreiter & Schmidhuber (1997), and were refined and popularized by many people in following work. They work tremendously well on a large variety of problems, and are now widely used.
# >
# > LSTMs are explicitly designed to avoid the long-term dependency problem. Remembering information for long periods of time is practically their default behavior, not something they struggle to learn!
# >
# > All recurrent neural networks have the form of a chain of repeating modules of neural network.

# %% [markdown]
# You can find more details here: http://colah.github.io/posts/2015-08-Understanding-LSTMs/

# %%
def LSTM_model(prediction_day):
    
    model = Sequential()
    
    model.add(LSTM(units = 500, return_sequences = True, input_shape = (x_train.shape[1],1)))
    model.add(Dropout(0.2))

    model.add(LSTM(units = 500, return_sequences = True))
    model.add(Dropout(0.2))

    model.add(LSTM(units = 500))
    model.add(Dropout(0.2))
    
    model.add(Dense(units=prediction_day))
    
    return model

# %% [markdown]
# **<font size="2"><a href="#summary">Back to summary</a></font>**
#
# ----

# %% [markdown]
# # <div id="chap4">4. Training

# %%
# model = LSTM_model()
# model.summary()
# model.compile(optimizer='adam', loss='mean_squared_error')

# # Define callbacks
# # Save weights only for best model
# checkpointer = ModelCheckpoint(filepath = 'weights_best.hdf5', verbose = 2, save_best_only = True)
# earlystopper = EarlyStopping(monitor = 'val_loss', patience = 5, verbose = 2)

# history = model.fit(x_train, y_train, epochs=25, batch_size = 32, callbacks = [checkpointer, earlystopper], validation_split = 0.2)

# # plot loss curves
# plt.plot(history.history['loss'], label='train')
# plt.plot(history.history['val_loss'], label='validation')
# plt.legend()
# plt.show()

# %%
model = LSTM_model(prediction_day)
model.summary()
model.compile(optimizer='adam', 
              loss='mean_squared_error')
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_12 (LSTM)              (None, 30, 500)           1004000
#
#  dropout_12 (Dropout)        (None, 30, 500)           0
#
#  lstm_13 (LSTM)              (None, 30, 500)           2002000
#
#  dropout_13 (Dropout)        (None, 30, 500)           0
#
#  lstm_14 (LSTM)              (None, 500)               2002000
#
#  dropout_14 (Dropout)        (None, 500)               0
#
#  dense_4 (Dense)             (None, 10)                5010
#
# =================================================================
# Total params: 5,013,010
# Trainable params: 5,013,010
# Non-trainable params: 0
# _________________________________________________________________

# %%
# # Define callbacks

# # Save weights only for best model
# checkpointer = ModelCheckpoint(filepath = 'weights_best.hdf5', 
#                                verbose = 2, 
#                                save_best_only = True)

# model.fit(x_train, 
#           y_train, 
#           epochs=25, 
#           batch_size = 32,
#           callbacks = [checkpointer])

# %%
# Define callbacks
# Save weights only for best model
checkpointer = ModelCheckpoint(filepath = 'weights_best.hdf5', verbose = 2, save_best_only = True)
earlystopper = EarlyStopping(monitor = 'val_loss', patience = 5, verbose = 2)

history = model.fit(x_train, y_train, epochs=25, batch_size = 32, callbacks = [checkpointer, earlystopper], validation_split = 0.2)
# Out:
# Epoch 1/25
# 10/10 [==============================] - ETA: 0s - loss: 0.8365
# Epoch 1: val_loss improved from inf to 0.59858, saving model to weights_best.hdf5
# 10/10 [==============================] - 21s 1s/step - loss: 0.8365 - val_loss: 0.5986
# Epoch 2/25
# 10/10 [==============================] - ETA: 0s - loss: 0.4354
# Epoch 2: val_loss improved from 0.59858 to 0.20255, saving model to weights_best.hdf5
# 10/10 [==============================] - 8s 821ms/step - loss: 0.4354 - val_loss: 0.2025
# Epoch 3/25
# 10/10 [==============================] - ETA: 0s - loss: 0.2122
# Epoch 3: val_loss improved from 0.20255 to 0.16550, saving model to weights_best.hdf5
# 10/10 [==============================] - 8s 832ms/step - loss: 0.2122 - val_loss: 0.1655
# Epoch 4/25
# 10/10 [==============================] - ETA: 0s - loss: 0.1731
# Epoch 4: val_loss did not improve from 0.16550
# 10/10 [==============================] - 8s 819ms/step - loss: 0.1731 - val_loss: 0.2048
# Epoch 5/25
# 10/10 [==============================] - ETA: 0s - loss: 0.1770
# Epoch 5: val_loss improved from 0.16550 to 0.14150, saving model to weights_best.hdf5
# 10/10 [==============================] - 8s 837ms/step - loss: 0.1770 - val_loss: 0.1415
# Epoch 6/25
# 10/10 [==============================] - ETA: 0s - loss: 0.1438
# Epoch 6: val_loss improved from 0.14150 to 0.11461, saving model to weights_best.hdf5
# 10/10 [==============================] - 9s 888ms/step - loss: 0.1438 - val_loss: 0.1146
# Epoch 7/25
# 10/10 [==============================] - ETA: 0s - loss: 0.1365
# Epoch 7: val_loss did not improve from 0.11461
# 10/10 [==============================] - 9s 881ms/step - loss: 0.1365 - val_loss: 0.2150
# Epoch 8/25
# 10/10 [==============================] - ETA: 0s - loss: 0.1476
# Epoch 8: val_loss improved from 0.11461 to 0.11107, saving model to weights_best.hdf5
# 10/10 [==============================] - 9s 897ms/step - loss: 0.1476 - val_loss: 0.1111
# Epoch 9/25
# 10/10 [==============================] - ETA: 0s - loss: 0.0986
# Epoch 9: val_loss improved from 0.11107 to 0.05555, saving model to weights_best.hdf5
# 10/10 [==============================] - 9s 905ms/step - loss: 0.0986 - val_loss: 0.0556
# Epoch 10/25
# 10/10 [==============================] - ETA: 0s - loss: 0.0598
# Epoch 10: val_loss improved from 0.05555 to 0.03091, saving model to weights_best.hdf5
# 10/10 [==============================] - 9s 957ms/step - loss: 0.0598 - val_loss: 0.0309
# Epoch 11/25
# 10/10 [==============================] - ETA: 0s - loss: 0.0398
# Epoch 11: val_loss improved from 0.03091 to 0.01483, saving model to weights_best.hdf5
# 10/10 [==============================] - 9s 951ms/step - loss: 0.0398 - val_loss: 0.0148
# Epoch 12/25
# 10/10 [==============================] - ETA: 0s - loss: 0.0305
# Epoch 12: val_loss did not improve from 0.01483
# 10/10 [==============================] - 9s 936ms/step - loss: 0.0305 - val_loss: 0.0684
# Epoch 13/25
# 10/10 [==============================] - ETA: 0s - loss: 0.0397
# Epoch 13: val_loss did not improve from 0.01483
# 10/10 [==============================] - 9s 900ms/step - loss: 0.0397 - val_loss: 0.0331
# Epoch 14/25
# 10/10 [==============================] - ETA: 0s - loss: 0.0302
# Epoch 14: val_loss improved from 0.01483 to 0.00962, saving model to weights_best.hdf5
# 10/10 [==============================] - 9s 913ms/step - loss: 0.0302 - val_loss: 0.0096
# Epoch 15/25
# 10/10 [==============================] - ETA: 0s - loss: 0.0208
# Epoch 15: val_loss did not improve from 0.00962
# 10/10 [==============================] - 9s 904ms/step - loss: 0.0208 - val_loss: 0.0103
# Epoch 16/25
# 10/10 [==============================] - ETA: 0s - loss: 0.0202
# Epoch 16: val_loss did not improve from 0.00962
# 10/10 [==============================] - 9s 918ms/step - loss: 0.0202 - val_loss: 0.0117
# Epoch 17/25
# 10/10 [==============================] - ETA: 0s - loss: 0.0200
# Epoch 17: val_loss did not improve from 0.00962
# 10/10 [==============================] - 9s 888ms/step - loss: 0.0200 - val_loss: 0.0215
# Epoch 18/25
# 10/10 [==============================] - ETA: 0s - loss: 0.0263
# Epoch 18: val_loss did not improve from 0.00962
# 10/10 [==============================] - 9s 907ms/step - loss: 0.0263 - val_loss: 0.0197
# Epoch 19/25
# 10/10 [==============================] - ETA: 0s - loss: 0.0371
# Epoch 19: val_loss did not improve from 0.00962
# 10/10 [==============================] - 9s 892ms/step - loss: 0.0371 - val_loss: 0.0623
# Epoch 19: early stopping

# %%
# Loss
fig, ax = plt.subplots(figsize=(8,4))
plt.title('loss')
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss', linestyle='--')
plt.legend()
plt.show()

# %% [markdown]
# **<font size="2"><a href="#summary">Back to summary</a></font>**
#
# ----

# %% [markdown]
# # <div id="chap5">5. Predictions

# %%
# test model accuracy on existing data

actual_prices = test_data['Close'].values
total_dataset = pd.concat((train_data['Close'], test_data['Close']), axis=0)
model_inputs = total_dataset[len(total_dataset)-len(test_data)-base_day:].values
model_inputs = model_inputs.reshape(-1,1)
model_inputs = scaler.fit_transform(model_inputs)

# %%
plt.plot(model_inputs)

# %%
x_test = []
y_test = []
for x in range(base_day+prediction_day, len(model_inputs)):
    x_test.append(model_inputs[x-base_day-prediction_day:x-prediction_day, 0])
    y_test.append(model_inputs[x-prediction_day:x, 0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1] ,1))

predicted_prices = model.predict(x_test)
predicted_prices = scaler.inverse_transform(predicted_prices)
print(f"predicted_prices: {predicted_prices[0]}")
print(f"predicted_prices: {predicted_prices[50]}")
# Out:
# 3/3 [==============================] - 2s 320ms/step
# predicted_prices: [ 0.68589    -0.42758787 -1.247355   -0.9063205  -0.58320343 -0.7395667
#   0.38890564  1.2653902   0.90943897  0.5553262 ]
# predicted_prices: [ 0.68589    -0.42758787 -1.247355   -0.9063205  -0.58320343 -0.7395667
#   0.38890564  1.2653902   0.90943897  0.5553262 ]

# %%
plt.figure(figsize=(20, 8))
for i in range(0, 50):
    plt.plot(predicted_prices[i], label=f"predicted {i}")
plt.title(f"{COMPANY} share price")
plt.xlabel("time")
plt.ylabel(f"{COMPANY} share price")
# plt.xlim(0, 9)
# plt.ylim(400, 510)
# plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.plot(actual_prices, color='black', label=f"Actual {COMPANY} price")
for i in range(0, 50, 5):
    plt.plot(predicted_prices[i], label=f"predicted {COMPANY} price")
plt.title(f"{COMPANY} share price")
plt.xlabel("time")
plt.ylabel(f"{COMPANY} share price")
# plt.xlim(0,9)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.plot(actual_prices, color='black', label=f"Actual price")
for i in range(0, len(predicted_prices), 3):
    start = i
    singal = predicted_prices[start]
    plt.plot(range(start,len(singal)+start), singal, label=f"predicted{i}")
plt.title(f"{COMPANY} share price")
plt.xlabel("time")
plt.ylabel(f"{COMPANY} share price")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.plot(actual_prices, color='black', label=f"Actual {COMPANY} price")
start = 8
singal = predicted_prices[start]
plt.plot(range(start,len(singal)+start), singal, color= 'green', label=f"predicted {COMPANY} price")
plt.title(f"{COMPANY} share price")
plt.xlabel("time")
plt.ylabel(f"{COMPANY} share price")
plt.xlim(0, 50)
# plt.ylim(400, 510)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.plot(actual_prices, color='black', label=f"Actual {COMPANY} price")
for i in range(0, len(predicted_prices), 7):
    start = i
    singal = predicted_prices[start]
    plt.plot(range(start,len(singal)+start), singal, color= 'green', label=f"predicted {COMPANY} price")
plt.title(f"{COMPANY} share price")
plt.xlabel("time")
plt.ylabel(f"{COMPANY} share price")

plt.legend()
plt.show()

# %%
for num in range(0, 5):
    plt.figure(figsize=(20, 8))
    for i in range(num, num+1):
        start = i
        singal = x_test[start]
        plt.plot(range(start,len(singal)+start), singal, label=f"x_test{i}")
    for i in range(num, num+1):
        start = i
        singal = y_test[start]
        plt.plot(range(start+len(x_test[start]),len(singal)+len(x_test[start])+start), singal, label=f"y_test{i}")
    for i in range(num, num+1):
        start = i
        singal = predicted_prices[start]
        plt.plot(range(start+len(x_test[start]),len(singal)+len(x_test[start])+start), singal, label=f"y_predict{i}")
    plt.xlabel("time")
    plt.title(f"data{i}", fontsize=40)
    plt.legend(fontsize=40)
    plt.show()
